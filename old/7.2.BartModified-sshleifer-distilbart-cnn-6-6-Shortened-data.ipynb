# %%
import torch
from torch import nn
from torch.nn import CrossEntropyLoss
from transformers import BartForConditionalGeneration, AutoTokenizer
import copy
import matplotlib.pylab as plt

# %%
model_checkpoint = "sshleifer/distilbart-cnn-6-6"
batch_size = 2
epochs = 4

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Tue Mar 22 01:25:08 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-PCIE-40GB      Off  | 00000000:01:00.0 Off |                    0 |
# | N/A   30C    P0    38W / 250W |   1103MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  A100-PCIE-40GB      Off  | 00000000:41:00.0 Off |                    0 |
# | N/A   69C    P0   241W / 250W |  36286MiB / 40536MiB |     82%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  A100-PCIE-40GB      Off  | 00000000:81:00.0 Off |                    0 |
# | N/A   30C    P0    34W / 250W |      3MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  A100-PCIE-40GB      Off  | 00000000:C1:00.0 Off |                    0 |
# | N/A   31C    P0    34W / 250W |      3MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  A100-PCIE-40GB      Off  | 00000000:E1:00.0 Off |                    0 |
# | N/A   31C    P0    36W / 250W |      3MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   2026001      C   python                            603MiB |
# |    0   N/A  N/A   2839719      C   python                            497MiB |
# |    1   N/A  N/A    641896      C   python                          36283MiB |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device('cuda:4' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=4)

# %%
# define the function
def shift_tokens_right(input_ids: torch.Tensor, pad_token_id: int, decoder_start_token_id: int):
    """
    Shift input ids one token to the right.
    """
    shifted_input_ids = input_ids.new_zeros(input_ids.shape)
    shifted_input_ids[:, 1:] = input_ids[:, :-1].clone()
    shifted_input_ids[:, 0] = decoder_start_token_id

    if pad_token_id is None:
        raise ValueError("self.model.config.pad_token_id has to be defined.")
    # replace possible -100 values in labels by `pad_token_id`
    shifted_input_ids.masked_fill_(shifted_input_ids == -100, pad_token_id)

    return shifted_input_ids


# define the class
class MLT(nn.Module):
    
    def __init__(self, model_checkpoint):
      super(MLT, self).__init__()

      self.model = BartForConditionalGeneration.from_pretrained(model_checkpoint)
      self.tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

      self.encoder = self.model.get_encoder()

      self.decoder1 = self.model.get_decoder()
      self.decoder2 = copy.deepcopy(self.decoder1)

      self.lm_head1 = self.model.get_output_embeddings()
      self.lm_head2 = copy.deepcopy(self.lm_head1)

    def get_config(self):
      return self.model.config

    def get_decoder(self):
      return self.decoder1

    def get_lm_head(self):
      return self.lm_head1

    def get_final_logits_bias(self):
      return self.model.final_logits_bias

    def get_tokenizer(self):
      return self.tokenizer

    def forward(self, text, summary1, summary2):
      # inputs = self.tokenizer.encode(text, return_tensors="pt")
      # target1 = self.tokenizer.encode(summary1, return_tensors="pt")
      # target2 = self.tokenizer.encode(summary2, return_tensors="pt")

      inputs = text
      target1 = summary1
      target2 = summary2

      encoder_outputs = self.encoder(inputs)

      decoder_input_ids1 = shift_tokens_right(
                    target1, self.model.config.pad_token_id, self.model.config.decoder_start_token_id
                )
      
      decoder_input_ids2 = shift_tokens_right(
                    target2, self.model.config.pad_token_id, self.model.config.decoder_start_token_id
                )
      
      
      decoder_outputs1 = self.decoder1(
          decoder_input_ids1, 
          encoder_hidden_states=encoder_outputs[0], 
          use_cache = False,
          output_attentions=self.model.config.output_attentions,
          output_hidden_states=self.model.config.output_hidden_states,
          return_dict=self.model.config.use_return_dict,
          ) 

      decoder_outputs2 = self.decoder2(
          decoder_input_ids2, 
          encoder_hidden_states=encoder_outputs[0], 
          use_cache = False,
          output_attentions=self.model.config.output_attentions,
          output_hidden_states=self.model.config.output_hidden_states,
          return_dict=self.model.config.use_return_dict,
          )  

      lm_logits1 = self.lm_head1(decoder_outputs1[0]) + self.model.final_logits_bias
      lm_logits2 = self.lm_head2(decoder_outputs2[0]) + self.model.final_logits_bias   

      masked_lm_loss1 = None
      masked_lm_loss2 = None
      loss_fct = CrossEntropyLoss()
      masked_lm_loss1 = loss_fct(lm_logits1.view(-1, self.model.config.vocab_size), target1.view(-1))
      masked_lm_loss2 = loss_fct(lm_logits2.view(-1, self.model.config.vocab_size), target2.view(-1))
      
      # return {
      #     'loss1': masked_lm_loss1, 
      #     'loss2': masked_lm_loss2,
      #     'encoder_outputs': encoder_outputs
      #     }

      return (masked_lm_loss1, masked_lm_loss2, encoder_outputs)


# create the object
model = MLT(model_checkpoint)

# %%
model.to(device)
# Out:
# MLT(
#   (model): BartForConditionalGeneration(
#     (model): BartModel(
#       (shared): Embedding(50264, 1024, padding_idx=1)
#       (encoder): BartEncoder(
#         (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#         (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#         (layers): ModuleList(
#           (0): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (decoder): BartDecoder(
#         (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#         (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#         (layers): ModuleList(
#           (0): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (lm_head): Linear(in_features=1024, out_features=50264, bias=False)
#   )
#   (encoder): BartEncoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder1): BartDecoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder2): BartDecoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head1): Linear(in_features=1024, out_features=50264, bias=False)
#   (lm_head2): Linear(in_features=1024, out_features=50264, bias=False)
# )

# %%
import pickle
with open('ami_short_fn.pkl', 'rb') as f:
    ami = pickle.load(f)

# %%
transcripts = ami['transcripts']
abs_summaries = ami['summaries']
ext_summaries = ami['summaries']


print(len(transcripts))
print(len(abs_summaries))
print(len(ext_summaries))
# Out:
# 137
# 137
# 137

# %%
from sklearn.model_selection import train_test_split

train_transcripts, val_transcripts, train_abs_summaries, val_abs_summaries = train_test_split(transcripts, abs_summaries, test_size=.2)
_, _, train_ext_summaries, val_ext_summaries = train_test_split(transcripts, ext_summaries, test_size=.2)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_transcripts_encodings = tokenizer(train_transcripts, truncation=True, padding=True)
val_transcripts_encodings = tokenizer(val_transcripts, truncation=True, padding=True)

with tokenizer.as_target_tokenizer():
  train_abs_summaries_encodings = tokenizer(train_abs_summaries, truncation=True, padding=True)
  val_abs_summaries_encodings = tokenizer(val_abs_summaries, truncation=True, padding=True)

  train_ext_summaries_encodings = tokenizer(train_ext_summaries, truncation=True, padding=True)
  val_ext_summaries_encodings = tokenizer(val_ext_summaries, truncation=True, padding=True)

# %%
class MeetDataset(torch.utils.data.Dataset):
    def __init__(self, transcripts, abs_summaries, ext_summaries):
        self.transcripts = transcripts
        self.abs_summaries = abs_summaries
        self.ext_summaries = ext_summaries

    def __len__(self):
        return len(self.transcripts.input_ids)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.transcripts.items()}
        item["abs"] = torch.tensor(self.abs_summaries["input_ids"][idx])
        item["ext"] = torch.tensor(self.ext_summaries["input_ids"][idx])
        return item

    

train_dataset = MeetDataset(train_transcripts_encodings, train_abs_summaries_encodings, train_ext_summaries_encodings)
val_dataset = MeetDataset(val_transcripts_encodings, val_abs_summaries_encodings, val_ext_summaries_encodings)

# %%
train_dataset.__len__(), val_dataset.__len__()
# Out:
# (109, 28)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validation_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %%
from transformers import BartPretrainedModel
from transformers.modeling_outputs import Seq2SeqLMOutput

class DecoderForGeneration(BartPretrainedModel):

    def __init__(self, config, decoder, lm_head, final_logits_bias):
        super().__init__(config)
        
        self.config = config
        self.decoder = decoder
        self.lm_head = lm_head
        self.final_logits_bias = final_logits_bias

    # def get_encoder(self):
    #     return self.get_encoder()

    def get_decoder(self):
        return self.model.get_decoder()

    def resize_token_embeddings(self, new_num_tokens: int) -> nn.Embedding:
        new_embeddings = super().resize_token_embeddings(new_num_tokens)
        self._resize_final_logits_bias(new_num_tokens)
        return new_embeddings

    def _resize_final_logits_bias(self, new_num_tokens: int) -> None:
        old_num_tokens = self.final_logits_bias.shape[-1]
        if new_num_tokens <= old_num_tokens:
            new_bias = self.final_logits_bias[:, :new_num_tokens]
        else:
            extra_bias = torch.zeros((1, new_num_tokens - old_num_tokens), device=self.final_logits_bias.device)
            new_bias = torch.cat([self.final_logits_bias, extra_bias], dim=1)
        self.register_buffer("final_logits_bias", new_bias)

    def get_output_embeddings(self):
        return self.lm_head

    def set_output_embeddings(self, new_embeddings):
        self.lm_head = new_embeddings

    
    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        decoder_input_ids=None,
        decoder_attention_mask=None,
        head_mask=None,
        decoder_head_mask=None,
        cross_attn_head_mask=None,
        encoder_outputs=None,
        past_key_values=None,
        inputs_embeds=None,
        decoder_inputs_embeds=None,
        labels=None,
        use_cache=None,
        output_attentions=None,
        output_hidden_states=None,
        return_dict=None,
    ):
        r"""
        labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
            Labels for computing the masked language modeling loss. Indices should either be in `[0, ...,
            config.vocab_size]` or -100 (see `input_ids` docstring). Tokens with indices set to `-100` are ignored
            (masked), the loss is only computed for the tokens with labels in `[0, ..., config.vocab_size]`.

        Returns:
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        if labels is not None:
            # if use_cache:
            #     logger.warning("The `use_cache` argument is changed to `False` since `labels` is provided.")
            use_cache = False
            if decoder_input_ids is None and decoder_inputs_embeds is None:
                decoder_input_ids = shift_tokens_right(
                    labels, self.config.pad_token_id, self.config.decoder_start_token_id
                )

        decoder_outputs = self.decoder(
        decoder_input_ids, 
        encoder_hidden_states=encoder_outputs[0], 
        use_cache = False,
        output_attentions=self.config.output_attentions,
        output_hidden_states=self.config.output_hidden_states,
        return_dict=self.config.use_return_dict,
        )
        lm_logits = self.lm_head(decoder_outputs[0]) + self.final_logits_bias

        masked_lm_loss = None
        if labels is not None:
            loss_fct = CrossEntropyLoss()
            masked_lm_loss = loss_fct(lm_logits.view(-1, model.config.vocab_size), labels.view(-1))

        if not return_dict:
            output = (lm_logits,) + decoder_outputs[1:]
            return ((masked_lm_loss,) + output) if masked_lm_loss is not None else output

        return Seq2SeqLMOutput(
            loss=masked_lm_loss,
            logits=lm_logits,
            past_key_values=decoder_outputs.past_key_values,
            decoder_hidden_states=decoder_outputs.hidden_states,
            decoder_attentions=decoder_outputs.attentions,
            cross_attentions=decoder_outputs.cross_attentions,
            encoder_last_hidden_state=encoder_outputs.last_hidden_state,
            encoder_hidden_states=encoder_outputs.hidden_states,
            encoder_attentions=encoder_outputs.attentions,
        )

    def prepare_inputs_for_generation(
        self,
        decoder_input_ids,
        past=None,
        attention_mask=None,
        head_mask=None,
        decoder_head_mask=None,
        cross_attn_head_mask=None,
        use_cache=None,
        encoder_outputs=None,
        **kwargs
    ):
        # cut decoder_input_ids if past is used
        if past is not None:
            decoder_input_ids = decoder_input_ids[:, -1:]

        return {
            "input_ids": None,  # encoder_outputs is defined. input_ids not needed
            "encoder_outputs": encoder_outputs,
            "past_key_values": past,
            "decoder_input_ids": decoder_input_ids,
            "attention_mask": attention_mask,
            "head_mask": head_mask,
            "decoder_head_mask": decoder_head_mask,
            "cross_attn_head_mask": cross_attn_head_mask,
            "use_cache": use_cache,  # change this to avoid caching (presumably for debugging)
        }

    def prepare_decoder_input_ids_from_labels(self, labels: torch.Tensor):
        return shift_tokens_right(labels, self.config.pad_token_id, self.config.decoder_start_token_id)

    @staticmethod
    def _reorder_cache(past, beam_idx):
        reordered_past = ()
        for layer_past in past:
            # cached cross_attention states don't have to be reordered -> they are always the same
            reordered_past += (
                tuple(past_state.index_select(0, beam_idx) for past_state in layer_past[:2]) + layer_past[2:],
            )
        return reordered_past


myDecoderModel = DecoderForGeneration(model.get_config(), model.get_decoder(), model.get_lm_head(), model.get_final_logits_bias())

# %%
myDecoderModel.to(device)
# Out:
# DecoderForGeneration(
#   (decoder): BartDecoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50264, bias=False)
# )

# %%
from datasets import load_metric

metric = load_metric("rouge")

# %%
learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
import numpy as np
import nltk
nltk.download('punkt')
def train(model, train_loader, validation_loader, optimizer, epochs=100):
    i = 0
    useful_stuff = {'training_loss': [], 'validation_loss': []}  
    
    for epoch in range(epochs):
        print(epoch)
        # model.train()
        for i, data in enumerate(train_loader):
            data['input_ids'], data['abs'], data['ext'] = data['input_ids'].to(device), data['abs'].to(device), data['ext'].to(device)
            optimizer.zero_grad()
            output = model(data['input_ids'], data['abs'], data['ext'])
            loss = output[0] + output[1]
            loss.backward()
            optimizer.step()
            useful_stuff['training_loss'].append(loss.item())
            print(loss.item())

        print("Validation")
        model.eval()
        for i, data in enumerate(validation_loader):
            with torch.no_grad():
              data['input_ids'], data['abs'], data['ext'] = data['input_ids'].to(device), data['abs'].to(device), data['ext'].to(device)
              output = model(data['input_ids'], data['abs'], data['ext'])
              loss = output[0] + output[1]
              useful_stuff['validation_loss'].append(loss.item())
              print(loss.item())

              predictions = myDecoderModel.generate(data['input_ids'], encoder_outputs=output[2])
              labels = data['abs'].cpu()

              decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
              print(decoded_preds)
              # Replace -100 in the labels as we can't decode them.
              labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
              decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
              
              # Rouge expects a newline after each sentence
              decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
              decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]

              metric.add_batch(predictions=decoded_preds, references=decoded_labels)
              
        result = metric.compute(use_stemmer=True)
        # Extract a few results from ROUGE
        result = {key: value.mid.fmeasure * 100 for key, value in result.items()}

        result = {k: round(v, 4) for k, v in result.items()}
    
    return (useful_stuff, result)

training_results = train(model, train_loader, validation_loader, optimizer, epochs=epochs)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/tanik_1821cs08/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0
# 20.050567626953125
# 19.67141342163086
# 12.34854507446289
# 7.986984729766846
# 3.945970058441162
# 4.508349418640137
# 4.688532829284668
# 2.630837917327881
# 3.362532615661621
# 4.64561653137207
# 3.955313205718994
# 3.1837563514709473
# 2.8125081062316895
# 3.063981533050537
# 5.005764961242676
# 3.4633374214172363
# 3.200277805328369
# 4.723169803619385
# 2.412905216217041
# 2.7187819480895996
# 3.6341030597686768
# 3.0725016593933105
# 4.074567794799805
# 3.4020702838897705
# 3.3782453536987305
# 2.3107619285583496
# 3.3189635276794434
# 2.806607723236084
# 3.8812451362609863
# 3.235157012939453
# 1.8468313217163086
# 4.163167953491211
# 3.5049078464508057
# 2.9882895946502686
# 3.2973875999450684
# 2.5251567363739014
# 3.7760796546936035
# 2.6819345951080322
# 4.389279842376709
# 3.5966134071350098
# 3.1827025413513184
# 3.178431510925293
# 4.092580795288086
# 1.9698164463043213
# 2.3461854457855225
# 2.561826229095459
# 3.8248953819274902
# 4.129302024841309
# 3.070645570755005
# 2.9223620891571045
# 3.6710407733917236
# 3.72529673576355
# 4.40413236618042
# 4.017650127410889
# 3.401289463043213
# Validation
# 4.857890605926514
# ["The team decided to incorporate the logo of the company into the remote. They decided to have the logo incorporated into the device's colour scheme. The group decided to use the logo to incorporate into the design of the device. They also decided to include the logo logo in their logo. The team decided that they should incorporate the company logo in the design. The remote will have a more advanced circuit board. The prototype will have an integrated push button for the buttons. The design team will work on the buttons and the prototype will be based on the user interface. The project will be completed in time for the project to be completed by the end of the year.The remote will be made available in the", 'The Industrial Designer presented the working design of the remote control. The Industrial Designer discussed the idea of a remote control that could be used to communicate with the user. The industrial designer presented the prototype of a new remote that will have a black screen and a remote that can be used for the remote. The designer presented a prototype of the new remote control, which will be used on a remote, and the industrial designer discussed the concept of using infrared signals to communicate to the user with the power of the device. The group discussed the possibility of using a remote to communicate via a remote. They discussed the need for a remote with a black and white screen. The team decided that the remote should have a']
# 3.4617133140563965
# ['The industrial designer will be responsible for the design of the remote. The Industrial Designer will be in charge of the project. The industrial designer is responsible for designing the remote control. The team will work on the design for the remote, but the industrial designer has not yet begun working on the product. The group will have to work on a functional design or technical design. They will also have to come up with a new idea on how to make the remote easier to use. The project manager will be able to make a remote control for the television. The remote will be a user interface designer. The marketing team will be involved in the design and marketing of the product, but they will also work on', "The project manager opened the project documents. The project manager explained that the project will be called the Industrial Industrial Designer. The Industrial Designer discussed the project's first meeting. The industrial designer discussed the idea of a new television remote control. The group discussed the concept of a modern-style remote. They discussed the need for a modern design. The team decided to design a new version of the remote. The first meeting took place on the Smartboard. The next meeting will be the Industrial Designer, the industrial designer, and the project manager will discuss the project. The final meeting will take place in the industrial Designer.The Industrial Designer will work on a new remote.The Project Manager will work with the"]
# 3.7103419303894043
# ['The industrial designer and the industrial designer presented their ideas to the group. The industrial designer discussed the idea of using an old-looking remote. The group discussed the possibility of using solar cells to power the remote. They discussed the concept of a power cradle. The team decided to use a rubber rubber to make it easier to control the remote, and the group decided to have a rubber-based design. The designer and industrial designer decided to create a prototype of the prototype. The project manager discussed the prototype of a remote that could be powered by a battery. They also discussed the design for the remote that would be used in the future. They decided to make a prototype for the project. The design', 'The project manager will discuss the components of the remote. The industrial designer will also discuss the case material, the case materials, and the user interface. The Industrial Designer will discuss how to make the remote look and how to use a rubber case, rubber, rubber and rubber. The designer will discuss whether to use the rubber case or rubber case. The team will also decide whether to include a regular battery or kinetic energy source. The group will decide on whether to incorporate a regular energy source in the case. They will also consider the use of a rubber or rubber casing. The interface designer will consider the possibility of using a regular chip in the remote to make it easier for the user to control the']
# 5.65382194519043
# ['The Project Manager and the Industrial Designer will discuss the design of a new remote. They will work together to create a prototype for the new remote control. The industrial designer will work on a prototype that will be designed to be original, trendy, user friendly and functional. The project manager will work with the industrial designer to create the prototype. The team will also work on the prototype design for the remote. The remote will be made to be designed by the industrial industrial designer. The design will be based on the user interface. The prototype will be the product of the industrial design. The price of the product will be decided on the product. The product will have a price range of between five and', 'The interface designer presented a presentation of the prototype. The industrial designer presented her thoughts on the future of the remote. The marketing expert suggested that the remote should be small, easy to use, and have a fruit, vegetable design. The designer presented an oversized remote that could be used in the future. The interface designer suggested that a special case made out of plastic should be made of plastic that is strong, not using any harmful materials, should be recyclable, should have a special plastic case. The team decided that the case should be plastic, and that it should be easy to make. The group decided that they should use plastic to make the case. They also discussed that they would like']
# 3.6726956367492676
# ["The project manager will present the prototype to the industrial designer. The industrial designer will present a prototype of the prototype. The team will also present a presentation of the project manager's presentation. The group will also discuss the budget and the future of the device. The meeting will be held in New York, New York and New York. The first meeting will take place in the fall. The next meeting will include a production evaluation. The final meeting will also be held at the same time as the first meeting. The last meeting will discuss the meeting's budget, the budget, and the budget for the project. The budget will be decided on the next meeting's agenda.The team will decide on the", 'The Project Manager will present the findings of a study into what users want in the remote. He will also present the results of the research conducted by a group of 100 test subjects. The project manager will present his findings to the group. The group will then present their findings on what they think they want in their remote. They will also discuss the future of the remote, and the needs of the user demographic. The marketing expert will present their presentation on the product. The meeting will also address the product market. The team will discuss the need for a high-end, high-tech, low-end and low-tech technology. The research group will also look at the needs and needs of']
# 4.697618007659912
# ["The prototype presentation was presented by the Industrial Designer. The Industrial Designer presented the prototype presentation of the prototype. The industrial Designer discussed the budget for the project. The group discussed the project's budget and budget options. The team discussed the cost of the project, the amount of time they spent on the prototype, and how they would like to use the remote. They discussed the possibility of using the remote as a remote. The project manager suggested that the remote could be used for the remote, but the industrial designer suggested that it should be used on the remote for the power. The designers discussed the need for a remote with the remote to be able to be used in the remote with a remote that is", 'The project manager opened the meeting with a presentation of the meeting agenda. The industrial designer opened the presentation with a PowerPoint presentation. The project manager gave the presentation to the industrial designer. The team decided that they needed an ergonomic shape, the material that they chose was wood, the colour would be customised, and the material would be wood, so they could stain the wood. The group decided to use wood to create a customised case. The remote will have an LCD screen on the back. The prototype will have a voice recognition function and be able to turn off the voice recognition on the off button. The case will be made from wood and wood, and it will have the ability to']
# 4.198566436767578
# ["The Project Manager will present a prototype of the prototype. He will present the prototype to the audience. The Industrial Designer will also present a presentation of the project manager's presentation. The industrial designer will discuss the prototype for the project. The project manager will present his presentation to the group. The group will also discuss the design of the new prototype. The team will work on a prototype for a prototype that will be based on a banana. They will also work on the design for a banana, a banana and a tomato. The final product will be the final product of the industrial industrial design. The prototype will be a prototype based on an industrial design, based on the logo of the banana.", 'The project manager and the industrial designer discussed the design of the remote. The industrial designer and industrial designer presented the project presentation. The Industrial Designer and the Industrial Designer presented the prototype of the prototype. They discussed the features of their prototype, which included the use of a triangle base, a yellow, yellow, red, and a yellow and yellow button. The team discussed the possibility of incorporating fruit and vegetables in the remote, which they could integrate with the design. The group discussed the idea of using a low-tech chip. The designer and the team discussed how to integrate the chip with the base and the battery. They decided to use the prototype to make the remote more accessible to the user.']
# 4.722655773162842
# ["The meeting will be held in the same format as the last meeting. The group will discuss the latest fashion trends of the market. They will also consider the latest trends in the remote control market as a factor which will affect their sales, profit and sales. The meeting will also discuss the future of the remo remote control. The team will discuss how they will incorporate the latest trend in the market in the future. The project manager will present their findings to the group. The marketing expert will present the findings in the group's findings. The company will discuss their findings in their report on the market market report.The group will also present the results of their research into the market trends in their", 'The Industrial Designer and Industrial Designer presented their findings to the Industrial Designer. The Industrial Designer discussed the possibility of using a remote with a voice recognition device. They decided to use a voice-recognition device and a slide-out panel for the more advanced functions for the remote. The industrial Designer decided that the remote could be used in a remote that does not need to be used as a remote because it does not have a voice. They discussed the need to have a different shape and the need for a remote to be able to use the voice recognition feature. They also discussed the cost of the remote, which they would like to have to be replaced with a different color. They agreed that they should']
# 3.693187713623047
# ["The project manager presented the functional design meeting to the industrial designer. The industrial designer presented the project manager's presentation. The project manager discussed the technical and user interface requirements. The designer discussed the design of the remote. The group discussed the possibility of using a remote to control a television. The remote was designed to be a standard, not a specialised device. The team decided to use a remote that could be used to control the television. They decided to include a remote with a remote. They discussed how to make a remote for the remote that was not specialised. They also discussed the need to be able to use the remote to communicate with the user. The meeting was closed and the group", 'The project manager introduces the project manager to the project. The marketing expert is the marketing expert for the trendy, user friendly look. The industrial designer is the Industrial Designer, the industrial designer, and the Marketing Expert are the marketing experts for the new remote. The project manager will work on the working design, components design, and user interface design. The Industrial Designer will also work on how to make the remote look and design the remote. They will be able to draw the remote into shape. The group will work together on the design of the remote, and will work with the user interface designer. The remote will be designed to be original, trendy and user friendly. The team will work']
# 3.572281837463379
# ["The prototype was presented to the project manager and the industrial designer. The industrial designer presented the prototype to the team. The team decided to evaluate the prototype using a Word docent. The project manager gave the prototype a look at the prototype. The group decided to use a rubber rubber to cover the prototype's buttons. The marketing expert presented the product to the group, the marketing expert, and the group's marketing expert. They discussed the product's marketing strategy. The product designer gave the product a green light, a yellow rubber rubber, a green rubber rubber and a green plastic rubber. They decided to put the prototype on the back of the rubber rubber.The industrial designer decided to give the prototype", "The User Interface Designer and Industrial Designer will work out what they want to do with the remote. The User Interface designer will work with the Industrial Designer to come up with ideas for the remote to be a universal remote that everyone would like to use. The industrial designer will be responsible for the project. The user interface designer will also work on the project manager's agenda. The group will work on how to make the remote a universal universal remote. They will work together to create a modern, fun, different, modern and fun-looking device. The final meeting will take place in the early hours of the day. The marketing expert will be able to work on what the remote will look like."]
# 2.7444281578063965
# ["The project manager and industrial designer presented their findings to the project manager. The project manager presented the project evaluation criteria, the cost of the product, the market trends, and the technological aspect of the project. The industrial designer gave the group a presentation of their findings. The group then discussed the project's requirements, market trends and market trends for the product. The team decided to decide whether to use a wheel, a battery, rubber material, and a case with a rubber material to make it look like a banana. They decided to use the rubber material for the prototype. The final decision was to make the product look more fashionable. The marketing expert gave the presentation of his findings and the industrial designer", 'The project manager and the project manager will work together on the project. They will work on the functional design of the remote. The group will then work on how to make it look like a dog. The team will then decide whether to work on a remote control. The meeting will be held on the same day as the meeting. The remote will be used to control the remote, and the team will use the remote to control a remote. It will be the first time it has ever been used in a remote that can be controlled by a human or a human. The design will be designed to be original, not be trendy, appealing to a wide market. The first meeting will take place in']
# 4.818391799926758
# ['The project manager and the marketing expert discussed the needs of the project manager. The marketing expert and the industrial designer discussed the market market potential for the remote. The project manager discussed the need to find out if the market will be willing to pay more for the product. The industrial designer and marketing expert also discussed the cost of the remote control. The group decided that the product should be designed to appeal to the market. The team decided that they should be able to sell the product to the consumers. They decided that it should be more affordable. They were able to make a profit out of their profits out of the design and marketing. They discussed the potential of the product and marketing potential. The meeting', 'The Project Manager will present the prototype to the group. The User Interface Designer will also present the project manager and the designer will present them to the team. The Industrial Designer will then present the team with a prototype of the prototype. The team will then evaluate the costs of the project. The industrial designer will then show the team how they will work with the team to develop the prototype for the device. The project manager will then give the team the prototype and the team will work on the design. The group will then decide whether to use the prototype as well as the design for the product. The design team will also discuss the design of the device and the budget for the production. The marketing team']
# 3.3365883827209473
# ["The project manager and industrial designer presented their findings to a group of 40 people. The industrial designer and the industrial designer discussed their findings. The group discussed the findings of a report about an experiment that was conducted by the company's marketing team. The team discussed the results of the study and the findings. They discussed the possibility of using a remote control for children, elderly people and older people. They also discussed the need for bi-sized buttons, bi-size buttons, and how to make it look more like a remote. They decided to use a remote that could be used for the remote. The project manager suggested that a remote should be made for the elderly. The Industrial Designer and the", "The project manager and the industrial designer discussed the design of a new remote. The industrial designer and industrial designer will discuss the project's financial objective. The project manager will also discuss the marketing side of the project. The marketing expert will discuss how to sell the remote to the consumer. The remote will be designed to have an advantage over the competition. The team will also try to be user friendly. The group will also be able to use the remote as a remote. They will also decide whether to sell it to the general public. The product will have a price range of between five and ten euros and have a profit of fifty million Euros.The remote will have to be designed for the purpose of"]
# 4.327718734741211
# ['The Industrial Designer and Industrial Designer discussed the functional design of the remote. The Industrial Designer decided to go to individual actions for each of the group. The group decided to work on the working design. They decided to decide on the name of the project. The industrial designer and the industrial designer discussed the design and the marketing expert. The marketing expert and industrial designer decided to discuss the design. The project manager and the Industrial Designer will work together on the design of a remote. They will work on a remote that will be able to use the same design as the remote as the current one. The remote will be available in the United States. The team will be working on a prototype of a prototype that', 'The project manager will present the project to the group. The marketing expert will be the Marketing Expert for the project. The industrial designer will also be the project manager. The group will discuss the goals of the project, which will include the design of a new remote. The team will also try to design a new version of the remote that will be used in the future. The project manager and the group will work together to create a prototype. The remote will be designed to be trendy, user friendly, and will be able to use it as a remote. They will also work on a prototype that will have a whiteboard. The prototype will be based on the shape and shape of the device.']
# 1
# 2.8573977947235107
# 2.45282244682312
# 2.6043763160705566
# 2.1284334659576416
# 3.9047951698303223
# 3.5299630165100098
# 2.817312240600586
# 3.6491775512695312
# 1.9772224426269531
# 2.9339613914489746
# 2.7368946075439453
# 2.419452428817749
# 3.9476308822631836
# 2.489035129547119
# 3.132598876953125
# 1.56867253780365
# 3.9236674308776855
# 2.8798012733459473
# 3.32608962059021
# 2.8149850368499756
# 2.693601131439209
# 3.036858558654785
# 2.4277610778808594
# 3.1677169799804688
# 3.1805496215820312
# 3.3284616470336914
# 2.4549150466918945
# 1.8640880584716797
# 2.586318016052246
# 2.765826940536499
# 2.744964361190796
# 3.4949686527252197
# 2.678734064102173
# 2.85687255859375
# 3.274226665496826
# 2.1256814002990723
# 2.557766914367676
# 3.1445717811584473
# 3.854836940765381
# 2.7621254920959473
# 3.080988883972168
# 2.2550084590911865
# 2.455508232116699
# 2.8519415855407715
# 4.945863723754883
# 3.9988770484924316
# 2.89762544631958
# 2.298694610595703
# 3.51985764503479
# 3.4602575302124023
# 2.6466827392578125
# 3.083433151245117
# 2.3926446437835693
# 3.2526068687438965
# 2.2470719814300537
# Validation
# 4.518463611602783
# ["The project manager opened the meeting and gave a presentation of the components design. The project manager gave a brief overview of the project. The industrial designer presented the components and the project manager presented the case design. They discussed the materials and materials used for the remote. The team decided to incorporate the logo logo into the device's colour scheme. The group decided to use the company logo to incorporate it into the design. It was decided to include the logo in its colour scheme on the device. The remote will have an integrated push button for the buttons. It will have a speech recognition function. It would be possible to use a rubber case to make the remote easier to use. The prototype will be made", 'The Project Manager presented the project manager and Industrial Designer presented the working design of the remote control. They discussed a flip open design, reducing the size of the control, an electronic panel for further features like programming and programming. The industrial designer presented a working design, presented the industrial designer and presented the Industrial Designer and the Industrial designer. The project manager presented the group of industrial designers. The group discussed their ideas for a remote control that could be used to control a TV, video equipment, and the group discussed the design of a remote. The marketing expert presented the team with a PowerPoint presentation. The Industrial Designer gave the group a presentation of their ideas and presented their ideas. The Project Manager']
# 3.243563413619995
# ["The project manager introduced the project manager and the industrial designer. The industrial designer discussed the project's marketing and product plan. The project manager discussed the marketing and marketing of the project. The Industrial Designer presented the project plan, the marketing plan, and the project management. The group then discussed the product and marketing. They discussed the remote control design. The team discussed the cost of the remote, and how they would like to make it easier to use. They decided to make a remote control for television. They also discussed how to make the remote more user friendly. The remote control will cost between $100 and $200. The marketing team will work on the project budget. They will discuss the", 'The project manager opened the project documents and opened the meeting. The project manager gave the project manager a brief overview of the project. The industrial designer gave the group a look at the project plan. The group then discussed their ideas for the project, which included the idea of a new remote control. The team then discussed the project budget. They decided that they would like to have a new version of the remote. They discussed how to make it look and how to use it. They then decided that it should be a modern design, and that they should make it more functional. They also discussed the possibility of using a rubber ball pen and rubber rubber rubber ball. They were told that they could not']
# 3.374756336212158
# ["The project manager opened the meeting and opened the agenda. The industrial designer introduced the project manager and the industrial designer. The marketing expert opened the group's agenda and gave the group a brief overview of the project. The group then opened their agenda and discussed their ideas for the remote control. The project manager then opened the project with the group discussing their ideas. The team discussed the idea of using a power cradle to power the remote. They discussed using solar cells, and how they would like to use a rubber-powered device. They also discussed using a rubber rubber device and rubber rubber. They decided to use the rubber rubber to make the remote more environmentally friendly. They then decided to make a rubber", "The project manager opened the meeting and discussed the components concept. The industrial designer discussed the case material, the case materials, and the user interface. The user interface designer discussed how to represent the user's needs, and how to use the buttons, buttons, and buttons. The project manager presented the project manager and the industrial designer. The group then discussed the materials and materials available for the project. They discussed how they would like to make a remote that could be used in the future. The team decided to use a regular battery and kinetic energy source. They also discussed the use of a rubber case and rubber case. They decided that the user will be happy to have a nice remote. They were"]
# 5.347826957702637
# ['The Project Manager and the User Interface Designer opened the project meeting. They discussed the design of a new remote control. They decided that the remote should be original, trendy, user friendly, and have to be original and trendy. They also discussed the possibility of using a child lock or child lock. The project manager and the user interface designer opened the meeting and discussed the project budget for the new remote. The industrial designer and the industrial designer discussed how they would work together. The group then discussed the cost of the project and the project manager. They then decided that they should sell the remote for a profit. They will sell the product for a production cost of twelve fifty Euros. The remote', 'The interface designer presented the prototype prototype. The industrial designer presented her thoughts on what she would like to have a special case made out of plastic and plastic. The marketing expert presented the final minutes of the last meeting. She presented the case case made of plastic plastic, plastic, rubber, rubber and rubber. The user interface designer discussed how the case should be made and how to make it look like a rubber case. The project manager presented a prototype of the prototype. They discussed how they wanted to incorporate a speech recogniser into the remote. They decided that they should have a memory switch, a mute button in case the telephone rings or something else was lost. They also discussed how to']
# 3.402559995651245
# ["The project manager opened the meeting and gave the meeting agenda. The industrial designer presented the prototype presentation. The user interface designer presented a prototype of the device. The project manager presented the project manager's agenda, the industrial designer discussed the project budget, and the budget for the project. The marketing expert presented the case case design. The group then discussed the budget budget. They discussed the feasibility of the project and the cost of the prototype. They also discussed the possibility of using a solar chip. The team decided to use the solar chip to power the device, but did not decide whether to use it. The prototype was designed to be made of rubber, plastic, and plastic.The group discussed the", 'The Project Manager will present the findings of a study into what users want in this remote control. He will present his findings to the Project Manager and the Expert. They will also present their findings on what features they want in the remote. The Project Manager presented the results of the study to the group of users. The Manager will then present the results to the Group of Users. The Group will also discuss the needs of the project manager. The group will discuss the marketing strategy. The project manager will present their results on the project management strategy.The group will then discuss the product strategy strategy and marketing strategy for the project.The Group will work on a project strategy and the overall marketing strategy of the']
# 4.369990348815918
# ["The project manager and the industrial designer presented the prototype presentation. The industrial designer discussed the project budget. The project manager presented the project agenda and discussed the budget for the project. The group then discussed their budget and budget options for the product. The marketing expert presented the product to the group. They discussed the product's price range, and how they would like it to be marketed. The team decided to make the product more affordable. They also discussed the possibility of using an LCD screen. They decided to use the LCD screen instead of an LCD. The prototype was designed to be based on a mango-based design. The final product was designed for the industrial industrial design group.The group decided to", 'The project manager opened the meeting meeting agenda. The project manager gave a presentation of the prototype prototype. The industrial designer opened the project meeting agenda and gave the project manager an overview of the project. The user interface designer presented the prototype design. The marketing expert presented the final presentation. The group then discussed the final design of the remote control. They decided that they wanted to make a customised case with wood wood and wood and that the material would be customisable. The team decided to use wood wood. They also decided that the case should be wood-based and that they could stain the wood. The remote will be customised and have an ergonomic shape. They will be able']
# 3.9433224201202393
# ["The Project Manager and the Industrial Designer presented their findings to the group. They discussed the project manager and the industrial designer. The industrial designer presented the prototype prototype. The project manager presented the group's findings and the group discussed their findings. The group then discussed the product evaluation. The marketing expert presented the team's findings on the project. The team decided to use the project budget budget for the project and the budget budget. The budget budget budget was too small, and the team did not have enough resources to meet their budget budget requirements. They decided that they should not have to make a profit out of the profits from the project, and that they would not be able to meet the budget", 'The project manager and the user interface designer presented the project presentation. The industrial designer presented a prototype of the remote control. The group discussed the project budget, and the project manager presented the prototype. The project manager gave the group a brief overview of the project. They discussed the product and discussed the cost of the prototype, and how they would like to integrate the fruit and vegetables. The team decided to make a prototype. They decided to use clay and clay as a base for the remote. They also discussed the possibility of integrating fruit and vegetable components into the device. The remote will be made from clay. The prototype was designed by the industrial designer, the industrial industrial designer and the industrial']
# 4.404592037200928
# ["The project manager and the user interface designer presented their findings to the project manager. They discussed the market trends of the remote control market. They also discussed the latest fashion trends. The project manager presented the group's findings and discussed their findings in a recent market survey. The user interface interface designer suggested that the remote should be easy to use. The industrial designer suggested the remo remote should have a fancy design. The marketing expert suggested that it should be more technologically innovative and technologically innovative. The group also suggested that they should make a sponge lemon, orange and yellow. The team decided that they did not want to use rubber or rubber. They decided that the company should not use rubber.", 'The Project Manager opened the prototype prototype and opened it up. The Industrial Designer and Industrial Designer discussed the possibilities of using a remote with a voice recognition function. The Project Manager and the Industrial Designer decided that they should use a voice-recognizing device. They discussed the possibility of using voice recognition. They decided not to use a remote that had a non-remote-like shape because they did not really need to use it as a remote since they could just use their voice. They also decided to use the voice recognition feature to make it easier for users to use their own voice. The project manager opened up the prototype. The industrial designer and industrial designer discussed what they could do with the']
# 3.402120590209961
# ['The project manager opened the meeting and opened the agenda. The project manager then opened the project and gave the project manager a brief overview of the project. The industrial designer presented the technical functions and the user interface interface. The user interface designer explained that the remote control is not specialised and that it is not a specialised technology. The marketing expert presented the project management brief. The group then discussed the technical requirements of the product design. They discussed the marketing strategy. They decided that they should not have to change the remote design. The team decided that it should not change the design of the remote. The remote will not be specialised because it is too expensive. It will be easy to make', 'The project manager introduced the project and opened the project meeting. The project manager opened the meeting and gave the project manager a brief overview of the project. The marketing expert was the marketing expert for the trendy, user friendly look. The industrial designer will work on the working design, components design and components design, and the user interface designer will also work on user interface design. The group will work together on the project project. They will work with the project management team. The remote will be able to control a remote that can be controlled by a remote control. The team will use the remote to record their voice and record their movements. It will be available on the corporate website, but the']
# 3.3446059226989746
# ["The Project Manager presented the prototype prototype to the industrial designer. The industrial designer presented the project manager and the marketing expert. The marketing expert presented the product to the group. The group discussed the product's marketing strategy. They decided to evaluate the product using the marketing strategy based on the latest trends on user preferences. The team decided to use a Word docent to evaluate each item. The project manager gave the group a budget budget budget. The budget expert gave the budget budget and suggested that the product should be designed to appeal to young people. The user interface designer presented a prototype of the prototype. The interface designer gave the product a prototype and gave it a prototype.The industrial designer gave", "The User Interface Designer and Industrial Designer will work on the project manager's agenda. They will work together on what they think the remote will look like and what they want to do. The project manager will work with the user interface designer and the industrial designer. The marketing expert will work out what the user needs to do with the remote. The group will also work on how to make the remote look like a modern, fun, different, modern and fun. The user interface expert will be able to work on what the remote looks like. The remote will be a universal remote that everyone would like to use. The final meeting will take place in the future. The interface designer will have the"]
# 2.584477186203003
# ['The project manager presented the project evaluation criteria. The industrial designer presented the technical aspects of the project. The marketing expert gave the project manager a presentation. The project manager gave the group a summary of the meeting. The group then decided to evaluate the project and the cost of the product. The team decided to use a rubber material to make it look like a banana shaped case. They also decided to make a wheel with the rubber material around it. The final decision was to decide whether to use the rubber rubber material for the wheel. The prototype was designed to be technologically innovative, easy to use, fashion, and easy to find in a room. The user interface designer will work with the industrial designer', 'The Project Manager and the Industrial Designer discussed the project. They discussed the product design, the functional design, and the user interface design. They decided to use a remote control to control the remote control. The project manager and the industrial designer discussed how they would like to work together. The group then discussed their own ideas, which they decided to change their original design. The industrial designer and the project manager discussed their ideas for the remote. The user interface designer decided that the remote should be more user friendly and user-friendly. The remote will be able to control a remote that can be used on a human body. The marketing expert and industrial designer will work on the project site. The']
# 4.548890113830566
# ["The Project Manager and the Industrial Designer discussed the project manager's role role. The Industrial Designer and the Marketing Expert discussed their roles. The Marketing Expert and the Project Manager discussed the needs of the marketing expert. They discussed the market market market survey and discussed the advantages of the remote control. The Project Manager then decided that they should not have to change their design. The marketing expert and the industrial designer will work on the project project. The project manager will work with the group. The group will work together on the marketing and marketing issues. They will discuss the project management role of each of the project managers. The industrial designer and marketing expert will discuss their roles in the group's roles.", 'The Project Manager will present the prototype to the user interface designer. The User Interface Designer will also present the project manager and the industrial designer. They will evaluate the costs of the project and evaluate their production costs. The group will also evaluate the cost of the device. The interface designer will also discuss the project budget. The project manager will also give the group a budget budget budget for the project. The industrial designer will work on the project for the next two months. The marketing expert will work with the group to develop the product. The team will also work on a prototype for the device that will be sold in the fall.The group will work together on a project budget budget.The project manager']
# 3.105121612548828
# ["The project manager and industrial designer presented the project manager's presentation. The industrial designer and the industrial designer discussed their findings. The project manager presented the group's findings and presented their findings to the group. The group then discussed what the product will look like and how to make it look like. The marketing expert presented the product and presented it to the team. The team then discussed the product design. They decided to create their own version of the product. They then decided to use it as a remote control. They also discussed how they would like it to look like a TV remote control, and how they should make it more like a remote. They were told to make the remote look like", "The project manager and the project manager opened the meeting and discussed the project's financial objective. The project manager gave the group a brief overview of the project. The marketing expert gave a brief look at the product design. The user interface designer gave a look at a drawing of an orangutan. The industrial designer gave the user interface design instructions. The group then discussed the marketing strategy. The remote will be sold as a remote. It will cost between two and five Euros and have a price range of fifty and fifty million Euros. The interface designer will work on the project cost between five and ten Euros.The marketing expert will also work on a remote control design.The remote will not have a"]
# 4.0254926681518555
# ["The Project Manager opened the meeting and opened the agenda. The Industrial Designer presented the project manager and the Industrial Designer discussed the functional design of the remote. The Project Manager gave the group a brief overview of the project. The Marketing Expert gave a brief presentation about the project's marketing strategy. The industrial designer gave a presentation about how to incorporate the remote control design. The project manager opened the project management meeting. The marketing expert gave the presentation and the industrial designer opened the presentation. The group then opened the discussion about the product design and the marketing strategy for the product. The team decided to go through the marketing and marketing. They decided to use the marketing expert's knowledge about the remote design", "The project manager presented the project to the project manager and the marketing expert. The marketing expert discussed the project. The project manager gave the group a brief overview of the project and explained the project's goals and objectives. The group discussed the goals of their project. They discussed how they would like to design a new remote control. They decided that the project should be trendy, user friendly, and that it should be fashionable, user-friendly. They also discussed how to use the whiteboard and how to draw their favorite animals. The team decided that they should use a bird to make it look like a c-c-c. It was difficult to draw a picture of the animal and"]
# 2
# 3.5955095291137695
# 2.7185332775115967
# 2.2509241104125977
# 2.3093364238739014
# 2.342001438140869
# 3.42808198928833
# 3.131229877471924
# 3.7688865661621094
# 3.0155277252197266
# 2.4783267974853516
# 2.641744613647461
# 3.9125280380249023
# 2.125175952911377
# 2.806365966796875
# 2.584122896194458
# 3.3255205154418945
# 2.704538345336914
# 3.909972667694092
# 1.9433109760284424
# 2.96207332611084
# 2.208346128463745
# 2.5234241485595703
# 2.6161298751831055
# 2.0940988063812256
# 2.7323498725891113
# 2.587157726287842
# 2.085453748703003
# 2.592564105987549
# 1.7368220090866089
# 2.5565805435180664
# 3.765444278717041
# 2.628582239151001
# 2.317617893218994
# 2.35506272315979
# 2.90718936920166
# 2.6070713996887207
# 1.8455359935760498
# 3.195533514022827
# 2.153805732727051
# 3.4556679725646973
# 2.4307851791381836
# 2.1753435134887695
# 3.714446544647217
# 1.9771852493286133
# 2.4267807006835938
# 3.3526084423065186
# 2.486832857131958
# 2.51149320602417
# 2.5270586013793945
# 3.023141860961914
# 3.512624979019165
# 3.768239974975586
# 2.5543313026428223
# 2.035172939300537
# 2.701913833618164
# Validation
# 4.386419296264648
# ["The Project Manager opened the meeting and gave a presentation of the project. The Industrial Designer presented the project and discussed the components design. The Project Manager gave the group a brief overview of the team's decision-making process. The industrial designer presented the case design, the industrial designer, and the marketing expert. The group then presented their findings in each of the options for the buttons, the buttons and the buttons. The team decided to incorporate the company logo into the design of the remote. The project manager gave the team a brief presentation on the components of the device. The marketing expert presented the group's findings and the group discussed their findings on the product design.The group then discussed the", "The Project Manager opened the meeting. The Industrial Designer presented the working design of the remote control. The Marketing Expert presented the Industrial Designer and Industrial Designer. The Project Manager presented the project manager's presentation of the project and the industrial designer's presentation. The industrial designer presented the industrial design. The marketing expert presented the group of industrial designers and industrial designers. The project manager presented the team of industrialists and industrialists. The group then presented their presentation of their findings on the project. The team then discussed their findings and the group discussed the project budget. They discussed the possibility of a remote control that could be used to communicate with the TV. They decided to use an LCD screen. The"]
# 3.152733325958252
# ...
# 3.0964603424072266
# ["The project manager opened the meeting by stating that the team had made three prototypes. The industrial designer presented the prototype and discussed the requirements of the user interface. The team then discussed the project budget, the materials used for the prototype, and the budget for the project. The project manager presented the team's prototype and the overall cost of the prototype. The marketing expert presented the project and the team discussed the budget. The group discussed the possibility of using an LCD screen. The prototype will be made of rubber, plastic, and plastic.The team will use a rubber case.The remote will be powered by a single battery.The case will be covered in rubber.The prototype will cost about $100", 'The Project Manager will present the findings of a study conducted into what users want in this remote control. The Project Manager and the Expert will present their findings to the Project Expert. The Expert will also present the results of the research conducted by a group of 100 test subjects. The Marketing Expert presented the findings and presented the results to the Marketing Expert and the Project Manager. They discussed the needs of the project and the marketing expert. They concluded that the project manager should focus on the product market. They also discussed the need for an LCD display, and the need to include speech recognition. The project manager will present his findings on the project evaluation.The Marketing Expert will provide the results on the evaluation of']
# 4.163633346557617
# ['The project manager and the industrial designer presented the prototype presentation. The group discussed the project budget, and discussed the features and functions of the remote. The project manager then led the group to a discussion about the prototype. The industrial designer discussed the prototype design. The team decided to use the remote as a remote, and the group decided not to use it. The marketing expert suggested that the remote should be made of a fruit-shaped design. They discussed the possibility of using an LCD screen. They decided that they should not use the LCD screen, and that they would not use a touch screen. The prototype was designed to be simple and simple, but the team decided that it was not to be', 'The project manager opened the meeting by stating that the project had not yet completed its evaluation criteria. The project manager then gave the project manager a brief overview of the project. The marketing expert gave a presentation of the prototype. The industrial designer presented the prototype design. The user interface designer discussed the ergonomic design of the remote. The team decided to use wood and wood to create a customisable case. The remote will have an LCD screen on the flip panel. It will have a voice recognition function and be able to turn the TV on, volume on, channel on, and menu on the lefthand side.The remote will be made of plastic, plastic and rubber. The case will']
# 3.7232582569122314
# ['The project manager opened the meeting by saying that the team had made a prototype of the prototype. The project manager then gave the team instructions for the project. The team then discussed the project budget and the overall cost of the product. The group then decided that the project was too expensive and that they should not have a prototype. They then decided to make a prototype for the next project. They decided that they would not be able to afford a prototype that would be too expensive to produce. The prototype was designed for the industrial market, but the team did not like it. The marketing expert was disappointed that they did not have enough time to complete the task. The industrial designer was disappointed with the project', 'The project manager and the industrial designer presented the project to the team. The industrial designer and the user interface designer presented a prototype of the prototype. The team then discussed the features of their prototype, which included a fruit and vegetable design. The project manager then led the team to the next meeting and the team discussed the project budget. The group then decided to evaluate the prototype and the overall cost of the project. The remote will cost between $100 and $200.The remote will be made of clay, and the remote will have an LCD screen. The case will be fitted with a rubber casing. The battery will be placed on the base of the remote. The chip will be used in the']
# 4.16319465637207
# ['The project manager opened the meeting by stating that the group had decided to use the same format as the last meeting. The group then discussed the latest fashion trends of the market. They discussed the possibility of using a spongy-shaped remote. The project manager suggested that the remote should be made of rubber and rubber. The industrial designer suggested that it should be easy to use. The marketing expert suggested that they should use a fruit-themed remote control. The user interface designer suggested using a sponge lemon to make the remote look more organic. The team decided to incorporate the fruit and vegetables into the design of the remote. They decided that they did not want to use a rubber-based remote.', 'The project manager opened the meeting by reading the minutes from the previous meeting. The industrial designer and industrial designer discussed the prototype prototype. The project manager then opened the prototype and opened it up to the team members. The team then decided to use a slide-out panel instead of a touch-screen. The group then decided that they should use a voice recognition device. The marketing expert and the industrial designer will work on the prototype design. The prototype will be sold in the fall of the year. The remote will be made of rubber, plastic, and plastic.The remote will have a rubber casing.The prototype will not have a touch screen.The team will use a speech recognition chip.The']
# 3.1992430686950684
# ['The project manager opened the meeting by stating that the remote is not currently working. The industrial designer presented the technical functions of the remote and the user interface. The user interface designer discussed the technical requirements of the project. The marketing expert presented the project requirements and the project manager presented the functional design. The project manager gave the project budget for the project and the budget. The group then discussed the project costs. The remote will be sold at the end of the year.The remote will cost between $20 and $100.The group will not be able to afford to meet all the requirements.The team will work on a prototype.The prototype will be made of plastic, plastic and plastic.The', 'The project manager introduced the project and the project manager and the marketing expert. The project manager opened the meeting by stating that the project was going to be a success. The marketing expert and the user interface designer will work on the design of the remote. The team will work together on the functional design, components design, and user interface design. The remote will be made of rubber, plastic, plastic and plastic. It will be sold in the fall of the year.The remote will have a rechargeable battery. The battery will be powered by rechargeable batteries. The device will have an LCD screen. It can be used to record voice data. It has a battery charge. It could be used']
# 3.1329562664031982
# ["The project manager presented the prototype to the team and the industrial designer. The industrial designer gave the prototype a look and feel of the prototype. The marketing expert gave a look at the prototype and gave it a rating based on user preferences. The user interface designer gave an evaluation of each item. The team decided to use a rubber rubber to cover the prototype's buttons. The interface designer will use a scroll button. The remote will use an LCD screen.The remote will be made of rubber and plastic.The prototype will be sold on the internet.The marketing expert will test the prototype on the ground.The industrial designer will work on the prototype for the next two months.The team will evaluate the", "The Project Manager opened the meeting by saying that the project manager and the User Interface Designer had some ideas for the project. The Marketing Expert and the Industrial Designer presented their findings to the Project Manager. The Project Manager led the project and the Marketing Expert presented the findings of a survey of users' opinions on their favorite remote. The User Interface Interface Designer presented her ideas on what they wanted to do and how to make the remote look. The project manager led the meeting and the marketing expert presented the results of the survey. The group then discussed the requirements of the remote, which included the need to be a universal, easy to find, sturdy, easy-to-find locator function,"]
# 2.449403762817383
# ['The project manager opened the meeting by stating that the prototype looked like a banana. The marketing expert gave the project evaluation of the prototype. The industrial designer presented the prototype to the team and the team members. The project manager then led the team to evaluate the prototype and the overall cost of the product. The team then decided to make a final decision on the project. The prototype was designed to be technologically innovative, technologically innovative and easy to use, easy to find in a room, and have a case with rubber material around it. The group decided to use the rubber material to make it look more like a fruit. They also decided to include a voice-controlled device in the design.The team', 'The project manager and the industrial designer presented the project to the team. The project manager discussed the project budget and the overall cost of the project. The team then discussed the functional design of the remote. The group then discussed how to make the remote look like a bird, and how to use it in different shapes and colors. The remote will be made of rubber, plastic, plastic and plastic. It will be sold in the fall of the year. The prototype will be designed to appeal to a wide market.The remote will cost between $100 and $200.The prototype will have a battery charge of up to 50.The target price will be between 20 and 50. The target price is']
# 4.338146209716797
# ['The project manager and the industrial designer discussed the project budget. The marketing expert and the project manager discussed the role of each of them in the project. The project manager instructed the team to prepare a budget budget for the product. The industrial designer and the marketing expert discussed the product budget. They discussed the cost of the product, which they felt was too expensive. The team decided to use the budget budget to reduce the number of buttons available. The group decided to make a profit out of the profit. They decided to incorporate the design into their budget budget.The marketing expert will work with the project team.The team will work on the product design.The remote will be made of plastic and plastic', 'The project manager presented the project to the team and the team members. The project manager then gave the team a prototype of the device. The team then presented the prototype to the group. The group then discussed the costs of the project and the project management. They discussed the project budget and the production costs. The marketing expert presented the team the prototype. The industrial designer will work on the project for the next two months.The team will work together to complete the project.The marketing expert will work with the team to develop the product.The group will also work together on the next few months to prepare the product for the market.The prototype will be sold in the fall of the year.The']
# 2.9053502082824707
# ["The project manager and industrial designer presented the project to the group. The project manager recapped the minutes of the previous meeting. The industrial designer recapped some of the findings of the last meeting and presented them to the team. The marketing expert recapped a marketing report on the site. The user interface designer presented a presentation of the project. The group then discussed the project manager's duties and the industrial designer's duties. The team then decided to create a prototype of the prototype. The remote will be made of plastic and plastic.The remote will have a battery charge.The team will use the remote to make the remote look like it is made of rubber.The group will use a rubber rubber", 'The project manager opened the meeting by stating that the project had a financial objective of having a production cost lower than twelve point five Euros. The project manager then gave the project manager a brief overview of the project. The marketing expert gave a brief look at the project budget. The industrial designer gave a look at what he thought the project was going to look like. The user interface designer will work on the design of the remote. The remote will be made of rubber, plastic and plastic.The remote will have a rubber case.The marketing expert will be working on the product design.The industrial designer will be able to work on a prototype.The team will also work on making a prototype of the']
# 3.7927894592285156
# ['The project manager opened the meeting by saying that the group had discussed the functional design of the remote. The marketing expert gave a brief overview of the project. The project manager gave the group a brief look-in-the-air presentation. The industrial designer gave the project manager a look at the project budget. The group then went to the marketing expert. The team then discussed the technical requirements of the product. They discussed the features of the device. They decided that the remote should be a universal or specific device. The remote will be sold in the United States.The remote will have an LCD screen, a touch screen, and a touch-screen. It will be made of plastic and plastic', "The project manager introduced the project to the team and the marketing expert. The marketing expert introduced the team to the project and the project manager. The project manager opened the meeting by saying that the team had received an email about the project. The group then discussed the project's goals, which included designing a new remote. The team then decided to use the whiteboard to draw their favorite animal. The remote will be made of rubber and plastic.The remote will have a rubber case.The team will use rubber rubber to make the remote look like a rubber casing.The group will use a rubber rubber case to make it look more like a remote.The project will be completed by the end of the"]

# %%
plt.plot(training_results[0]['training_loss'], label="train")
plt.plot(training_results[0]['validation_loss'], label="val")
plt.ylabel('loss')
plt.xlabel('iterations')
plt.legend()
#plt.title('training loss iterations')

# %%
training_results[1]
# Out:
# {'rouge1': 40.203, 'rouge2': 16.3304, 'rougeL': 24.1974, 'rougeLsum': 38.3591}

# %%
# !nvidia-smi
