# %%
import torch
from torch import nn
from torch.nn import CrossEntropyLoss
from transformers import BartForConditionalGeneration, AutoTokenizer
import copy
import matplotlib.pylab as plt

# %%
model_checkpoint = "sshleifer/distilbart-cnn-6-6"
batch_size = 2
epochs = 4

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Thu Mar 17 14:11:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-PCIE-40GB      Off  | 00000000:01:00.0 Off |                    0 |
# | N/A   32C    P0    39W / 250W |   7581MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  A100-PCIE-40GB      Off  | 00000000:41:00.0 Off |                    0 |
# | N/A   70C    P0   139W / 250W |  40137MiB / 40536MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  A100-PCIE-40GB      Off  | 00000000:81:00.0 Off |                    0 |
# | N/A   33C    P0    36W / 250W |    586MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  A100-PCIE-40GB      Off  | 00000000:C1:00.0 Off |                    0 |
# | N/A   34C    P0    37W / 250W |    586MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  A100-PCIE-40GB      Off  | 00000000:E1:00.0 Off |                    0 |
# | N/A   35C    P0    39W / 250W |    586MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A    914655      C   .../obj_detection/bin/python     5979MiB |
# |    0   N/A  N/A   1876506      C   python                            499MiB |
# |    0   N/A  N/A   2026001      C   python                            603MiB |
# |    0   N/A  N/A   2839719      C   python                            497MiB |
# |    1   N/A  N/A    914655      C   .../obj_detection/bin/python      583MiB |
# |    1   N/A  N/A   3404078      C   python                          39551MiB |
# |    2   N/A  N/A    914655      C   .../obj_detection/bin/python      583MiB |
# |    3   N/A  N/A    914655      C   .../obj_detection/bin/python      583MiB |
# |    4   N/A  N/A    914655      C   .../obj_detection/bin/python      583MiB |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device('cuda:4' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=4)

# %%
# define the function
def shift_tokens_right(input_ids: torch.Tensor, pad_token_id: int, decoder_start_token_id: int):
    """
    Shift input ids one token to the right.
    """
    shifted_input_ids = input_ids.new_zeros(input_ids.shape)
    shifted_input_ids[:, 1:] = input_ids[:, :-1].clone()
    shifted_input_ids[:, 0] = decoder_start_token_id

    if pad_token_id is None:
        raise ValueError("self.model.config.pad_token_id has to be defined.")
    # replace possible -100 values in labels by `pad_token_id`
    shifted_input_ids.masked_fill_(shifted_input_ids == -100, pad_token_id)

    return shifted_input_ids


# define the class
class MLT(nn.Module):
    
    def __init__(self, model_checkpoint):
      super(MLT, self).__init__()

      self.model = BartForConditionalGeneration.from_pretrained(model_checkpoint)
      self.tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

      self.encoder = self.model.get_encoder()

      self.decoder1 = self.model.get_decoder()
      self.decoder2 = copy.deepcopy(self.decoder1)

      self.lm_head1 = self.model.get_output_embeddings()
      self.lm_head2 = copy.deepcopy(self.lm_head1)

    def get_config(self):
      return self.model.config

    def get_decoder(self):
      return self.decoder1

    def get_lm_head(self):
      return self.lm_head1

    def get_final_logits_bias(self):
      return self.model.final_logits_bias

    def get_tokenizer(self):
      return self.tokenizer

    def forward(self, text, summary1, summary2):
      # inputs = self.tokenizer.encode(text, return_tensors="pt")
      # target1 = self.tokenizer.encode(summary1, return_tensors="pt")
      # target2 = self.tokenizer.encode(summary2, return_tensors="pt")

      inputs = text
      target1 = summary1
      target2 = summary2

      encoder_outputs = self.encoder(inputs)

      decoder_input_ids1 = shift_tokens_right(
                    target1, self.model.config.pad_token_id, self.model.config.decoder_start_token_id
                )
      
      decoder_input_ids2 = shift_tokens_right(
                    target2, self.model.config.pad_token_id, self.model.config.decoder_start_token_id
                )
      
      
      decoder_outputs1 = self.decoder1(
          decoder_input_ids1, 
          encoder_hidden_states=encoder_outputs[0], 
          use_cache = False,
          output_attentions=self.model.config.output_attentions,
          output_hidden_states=self.model.config.output_hidden_states,
          return_dict=self.model.config.use_return_dict,
          ) 

      decoder_outputs2 = self.decoder2(
          decoder_input_ids2, 
          encoder_hidden_states=encoder_outputs[0], 
          use_cache = False,
          output_attentions=self.model.config.output_attentions,
          output_hidden_states=self.model.config.output_hidden_states,
          return_dict=self.model.config.use_return_dict,
          )  

      lm_logits1 = self.lm_head1(decoder_outputs1[0]) + self.model.final_logits_bias
      lm_logits2 = self.lm_head2(decoder_outputs2[0]) + self.model.final_logits_bias   

      masked_lm_loss1 = None
      masked_lm_loss2 = None
      loss_fct = CrossEntropyLoss()
      masked_lm_loss1 = loss_fct(lm_logits1.view(-1, self.model.config.vocab_size), target1.view(-1))
      masked_lm_loss2 = loss_fct(lm_logits2.view(-1, self.model.config.vocab_size), target2.view(-1))
      
      # return {
      #     'loss1': masked_lm_loss1, 
      #     'loss2': masked_lm_loss2,
      #     'encoder_outputs': encoder_outputs
      #     }

      return (masked_lm_loss1, masked_lm_loss2, encoder_outputs)


# create the object
model = MLT(model_checkpoint)

# %%
model.to(device)
# Out:
# MLT(
#   (model): BartForConditionalGeneration(
#     (model): BartModel(
#       (shared): Embedding(50264, 1024, padding_idx=1)
#       (encoder): BartEncoder(
#         (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#         (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#         (layers): ModuleList(
#           (0): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): BartEncoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (decoder): BartDecoder(
#         (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#         (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#         (layers): ModuleList(
#           (0): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (3): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (4): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#           (5): BartDecoderLayer(
#             (self_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): BartAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (lm_head): Linear(in_features=1024, out_features=50264, bias=False)
#   )
#   (encoder): BartEncoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartEncoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder1): BartDecoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder2): BartDecoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head1): Linear(in_features=1024, out_features=50264, bias=False)
#   (lm_head2): Linear(in_features=1024, out_features=50264, bias=False)
# )

# %%
from pathlib import Path

transcripts_dir = Path("./data/ami/transcripts")
abs_summaries_dir = Path("./data/ami/summaries/abstractive")
ext_summaries_dir = Path("./data/ami/summaries/extractive")

transcripts = []
abs_summaries = []
ext_summaries = []

for file in transcripts_dir.iterdir():
  transcripts.append(file.read_text())

for file in abs_summaries_dir.iterdir():
  abs_summaries.append(file.read_text())

for file in ext_summaries_dir.iterdir():
  ext_summaries.append(file.read_text())

print(len(transcripts))
print(len(abs_summaries))
print(len(ext_summaries))
# Out:
# 137
# 137
# 137

# %%
from sklearn.model_selection import train_test_split

train_transcripts, val_transcripts, train_abs_summaries, val_abs_summaries = train_test_split(transcripts, abs_summaries, test_size=.2)
_, _, train_ext_summaries, val_ext_summaries = train_test_split(transcripts, ext_summaries, test_size=.2)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_transcripts_encodings = tokenizer(train_transcripts, truncation=True, padding=True)
val_transcripts_encodings = tokenizer(val_transcripts, truncation=True, padding=True)

with tokenizer.as_target_tokenizer():
  train_abs_summaries_encodings = tokenizer(train_abs_summaries, truncation=True, padding=True)
  val_abs_summaries_encodings = tokenizer(val_abs_summaries, truncation=True, padding=True)

  train_ext_summaries_encodings = tokenizer(train_ext_summaries, truncation=True, padding=True)
  val_ext_summaries_encodings = tokenizer(val_ext_summaries, truncation=True, padding=True)

# %%
class MeetDataset(torch.utils.data.Dataset):
    def __init__(self, transcripts, abs_summaries, ext_summaries):
        self.transcripts = transcripts
        self.abs_summaries = abs_summaries
        self.ext_summaries = ext_summaries

    def __len__(self):
        return len(self.transcripts.input_ids)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.transcripts.items()}
        item["abs"] = torch.tensor(self.abs_summaries["input_ids"][idx])
        item["ext"] = torch.tensor(self.ext_summaries["input_ids"][idx])
        return item

    

train_dataset = MeetDataset(train_transcripts_encodings, train_abs_summaries_encodings, train_ext_summaries_encodings)
val_dataset = MeetDataset(val_transcripts_encodings, val_abs_summaries_encodings, val_ext_summaries_encodings)

# %%
train_dataset.__len__(), val_dataset.__len__()
# Out:
# (109, 28)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validation_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %%
from transformers import BartPretrainedModel
from transformers.modeling_outputs import Seq2SeqLMOutput

class DecoderForGeneration(BartPretrainedModel):

    def __init__(self, config, decoder, lm_head, final_logits_bias):
        super().__init__(config)
        
        self.config = config
        self.decoder = decoder
        self.lm_head = lm_head
        self.final_logits_bias = final_logits_bias

    # def get_encoder(self):
    #     return self.get_encoder()

    def get_decoder(self):
        return self.model.get_decoder()

    def resize_token_embeddings(self, new_num_tokens: int) -> nn.Embedding:
        new_embeddings = super().resize_token_embeddings(new_num_tokens)
        self._resize_final_logits_bias(new_num_tokens)
        return new_embeddings

    def _resize_final_logits_bias(self, new_num_tokens: int) -> None:
        old_num_tokens = self.final_logits_bias.shape[-1]
        if new_num_tokens <= old_num_tokens:
            new_bias = self.final_logits_bias[:, :new_num_tokens]
        else:
            extra_bias = torch.zeros((1, new_num_tokens - old_num_tokens), device=self.final_logits_bias.device)
            new_bias = torch.cat([self.final_logits_bias, extra_bias], dim=1)
        self.register_buffer("final_logits_bias", new_bias)

    def get_output_embeddings(self):
        return self.lm_head

    def set_output_embeddings(self, new_embeddings):
        self.lm_head = new_embeddings

    
    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        decoder_input_ids=None,
        decoder_attention_mask=None,
        head_mask=None,
        decoder_head_mask=None,
        cross_attn_head_mask=None,
        encoder_outputs=None,
        past_key_values=None,
        inputs_embeds=None,
        decoder_inputs_embeds=None,
        labels=None,
        use_cache=None,
        output_attentions=None,
        output_hidden_states=None,
        return_dict=None,
    ):
        r"""
        labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
            Labels for computing the masked language modeling loss. Indices should either be in `[0, ...,
            config.vocab_size]` or -100 (see `input_ids` docstring). Tokens with indices set to `-100` are ignored
            (masked), the loss is only computed for the tokens with labels in `[0, ..., config.vocab_size]`.

        Returns:
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        if labels is not None:
            # if use_cache:
            #     logger.warning("The `use_cache` argument is changed to `False` since `labels` is provided.")
            use_cache = False
            if decoder_input_ids is None and decoder_inputs_embeds is None:
                decoder_input_ids = shift_tokens_right(
                    labels, self.config.pad_token_id, self.config.decoder_start_token_id
                )

        decoder_outputs = self.decoder(
        decoder_input_ids, 
        encoder_hidden_states=encoder_outputs[0], 
        use_cache = False,
        output_attentions=self.config.output_attentions,
        output_hidden_states=self.config.output_hidden_states,
        return_dict=self.config.use_return_dict,
        )
        lm_logits = self.lm_head(decoder_outputs[0]) + self.final_logits_bias

        masked_lm_loss = None
        if labels is not None:
            loss_fct = CrossEntropyLoss()
            masked_lm_loss = loss_fct(lm_logits.view(-1, model.config.vocab_size), labels.view(-1))

        if not return_dict:
            output = (lm_logits,) + decoder_outputs[1:]
            return ((masked_lm_loss,) + output) if masked_lm_loss is not None else output

        return Seq2SeqLMOutput(
            loss=masked_lm_loss,
            logits=lm_logits,
            past_key_values=decoder_outputs.past_key_values,
            decoder_hidden_states=decoder_outputs.hidden_states,
            decoder_attentions=decoder_outputs.attentions,
            cross_attentions=decoder_outputs.cross_attentions,
            encoder_last_hidden_state=encoder_outputs.last_hidden_state,
            encoder_hidden_states=encoder_outputs.hidden_states,
            encoder_attentions=encoder_outputs.attentions,
        )

    def prepare_inputs_for_generation(
        self,
        decoder_input_ids,
        past=None,
        attention_mask=None,
        head_mask=None,
        decoder_head_mask=None,
        cross_attn_head_mask=None,
        use_cache=None,
        encoder_outputs=None,
        **kwargs
    ):
        # cut decoder_input_ids if past is used
        if past is not None:
            decoder_input_ids = decoder_input_ids[:, -1:]

        return {
            "input_ids": None,  # encoder_outputs is defined. input_ids not needed
            "encoder_outputs": encoder_outputs,
            "past_key_values": past,
            "decoder_input_ids": decoder_input_ids,
            "attention_mask": attention_mask,
            "head_mask": head_mask,
            "decoder_head_mask": decoder_head_mask,
            "cross_attn_head_mask": cross_attn_head_mask,
            "use_cache": use_cache,  # change this to avoid caching (presumably for debugging)
        }

    def prepare_decoder_input_ids_from_labels(self, labels: torch.Tensor):
        return shift_tokens_right(labels, self.config.pad_token_id, self.config.decoder_start_token_id)

    @staticmethod
    def _reorder_cache(past, beam_idx):
        reordered_past = ()
        for layer_past in past:
            # cached cross_attention states don't have to be reordered -> they are always the same
            reordered_past += (
                tuple(past_state.index_select(0, beam_idx) for past_state in layer_past[:2]) + layer_past[2:],
            )
        return reordered_past


myDecoderModel = DecoderForGeneration(model.get_config(), model.get_decoder(), model.get_lm_head(), model.get_final_logits_bias())

# %%
myDecoderModel.to(device)
# Out:
# DecoderForGeneration(
#   (decoder): BartDecoder(
#     (embed_tokens): Embedding(50264, 1024, padding_idx=1)
#     (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#     (layers): ModuleList(
#       (0): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): BartDecoderLayer(
#         (self_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): BartAttention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50264, bias=False)
# )

# %%
from datasets import load_metric

metric = load_metric("rouge")

# %%
learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
import numpy as np
import nltk
nltk.download('punkt')
def train(model, train_loader, validation_loader, optimizer, epochs=100):
    i = 0
    useful_stuff = {'training_loss': [], 'validation_loss': []}  
    
    for epoch in range(epochs):
        print(epoch)
        # model.train()
        for i, data in enumerate(train_loader):
            data['input_ids'], data['abs'], data['ext'] = data['input_ids'].to(device), data['abs'].to(device), data['ext'].to(device)
            optimizer.zero_grad()
            output = model(data['input_ids'], data['abs'], data['ext'])
            loss = output[0] + output[1]
            loss.backward()
            optimizer.step()
            useful_stuff['training_loss'].append(loss.item())
            print(loss.item())

        print("Validation")
        model.eval()
        for i, data in enumerate(validation_loader):
            with torch.no_grad():
              data['input_ids'], data['abs'], data['ext'] = data['input_ids'].to(device), data['abs'].to(device), data['ext'].to(device)
              output = model(data['input_ids'], data['abs'], data['ext'])
              loss = output[0] + output[1]
              useful_stuff['validation_loss'].append(loss.item())
              print(loss.item())

              predictions = myDecoderModel.generate(data['input_ids'], encoder_outputs=output[2])
              labels = data['abs'].cpu()

              decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
              print(decoded_preds)
              # Replace -100 in the labels as we can't decode them.
              labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
              decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
              
              # Rouge expects a newline after each sentence
              decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
              decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]

              metric.add_batch(predictions=decoded_preds, references=decoded_labels)
              
        result = metric.compute(use_stemmer=True)
        # Extract a few results from ROUGE
        result = {key: value.mid.fmeasure * 100 for key, value in result.items()}

        result = {k: round(v, 4) for k, v in result.items()}
    
    return (useful_stuff, result)

training_results = train(model, train_loader, validation_loader, optimizer, epochs=epochs)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/tanik_1821cs08/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0
# 19.73227310180664
# 19.418498992919922
# 12.108306884765625
# 7.194122314453125
# 7.317293643951416
# 7.557563304901123
# 7.494473457336426
# 6.816224575042725
# 6.439085483551025
# 5.52711296081543
# 5.905647277832031
# 6.435910701751709
# 6.1164045333862305
# 5.465237617492676
# 6.205121040344238
# 5.894718170166016
# 6.3509674072265625
# 5.904469013214111
# 5.566380500793457
# 5.455780982971191
# 5.729231357574463
# 5.89748477935791
# 5.454373836517334
# 5.871809959411621
# 5.468691825866699
# 5.8247904777526855
# 6.305272102355957
# 4.43688440322876
# 5.328738212585449
# 5.792892932891846
# 5.674355506896973
# 4.764590263366699
# 6.088944911956787
# 5.3227691650390625
# 4.881150722503662
# 5.867395401000977
# 5.5407185554504395
# 5.542469024658203
# 5.8657121658325195
# 6.350381851196289
# 5.288341999053955
# 5.943982124328613
# 5.467641830444336
# 5.292670726776123
# 5.664393424987793
# 5.873584270477295
# 5.403336524963379
# 5.659421920776367
# 5.651583194732666
# 5.38958215713501
# 5.35093355178833
# 5.753055095672607
# 5.002080917358398
# 4.749129295349121
# 5.253541946411133
# Validation
# 6.721706390380859
# ['The company decided to use a remote control for the remote control. The team decided that they needed to be able to use the remote to control the remote. The group decided that the remote should be used to control a remote. They decided that it should be a remote that could be used for a remote, and that it would be used in the future. They also discussed the idea of using a remote to make it easier to use. They discussed the possibility of using the remote for remote control and using it to make the remote remote control, and how to use it to communicate. The company decided that a remote would have to be used as a remote for the first time. The meeting', 'The project manager and the project manager will discuss the design of the remote. They will also discuss the cost of the project. The group will then decide whether to use a remote control. The team will then discuss the product design, and then decide if they will be able to make a remote with a remote. The project manager decided to use the remote to make the remote easier to use. He will also decide if it will be a remote that can be used with the remote, and if it can be easily accessed by remote control, and that it should be used to make it look like a remote, or not have to have a remote to be used. The meeting manager and project manager discussed']
# 7.316246032714844
# ["The project manager presented a presentation of the project. The project manager discussed the project manager's presentation presentation. He discussed the possibility of using a remote to control the remote. He also discussed the cost of the remote, and discussed the need for a remote. The team decided to use the remote to make the project more affordable. They discussed the idea of a remote that could be used in the future. The group decided that it should be used for the remote control. They also discussed how to use a remote control device. They decided that they would like to use it to control a remote with a remote and that it would be easy to find the remote and not be too expensive. The", 'The project manager and the designer discussed the project. The project manager decided that the project manager should be able to use a remote control. The designer decided to use the remote control to make the project easier to use. The group then decided to discuss the design of the remote. The team then decided that they should use it as a remote to control the remote, and that it should be used in the user interface. They discussed the design. They decided that it would be easy to use for the user to control. They also discussed how to use their remote control and how to make a remote. They then discussed the price of the project, which they would like to use to control it. The']
# 6.66091775894165
# ['The project manager. The project manager presented a list of criteria for the remote control. The group then discussed the design of the remote. The team then decided to decide whether to use the remote to control a remote. They decided to use a remote control to control the remote for the first time. They also discussed the need for a remote with a remote that can be easily controlled. They discussed the cost of the device and the amount of features that they would like to have. The final group discussed the remote and the need to be able to make it easier to use. They then discussed how to make the remote look like a remote, and how to use it to make a remote for a', "The first meeting will be held in the United States. The group will discuss the design of the remote. They will also discuss the financial implications of the project. The team will discuss how they would like to use the remote to make it look like a remote. The company will discuss their financial goals. They'll also discuss how to make the remote look more functional and more affordable. They have to discuss the possibility of using a remote that could be used in the future. They also have to decide if they will be able to use a remote with a remote control. The project manager will discuss what the company will use to make a remote, and if they can use it as a remote"]
# 7.258816719055176
# ['The Marketing Expert. The Marketing Expert will give a presentation. The User Interface guy will present a presentation of his presentation. He will also discuss the use of a remote control. The marketing expert will discuss the possibility of using the remote control to communicate with the user. The user interface guy will discuss how to use the remote to communicate. The group will then discuss the concept of the remote. They will then decide whether to put the remote on a banana remote. The project manager will then give the presentation of their presentation to the marketing expert. The team will discuss whether to use a remote to talk to the user about what they want to do with the remote and how to make the remote', "The project manager and the project manager presented the project to the group. The group discussed the project and discussed the design of the device. The team discussed how they would like to use the device to make it easier to use. The project manager discussed the product design and discussed how to make the device look and how to use it. The marketing expert discussed the idea of using the device as a remote control. The designer discussed the device's shape and the design and the user interface. They discussed the need to be able to use a remote. They also discussed the possibility of using a remote, remote control, and how they might use the remote to control the remote. The meeting was also discussed"]
# 7.4205474853515625
# ['The project manager and the project manager will discuss the components of the remote. The project manager discussed the idea of using rubber and rubber to make the remote look like a rubber case. He also discussed the possibility of using a rubber rubber case, rubber, plastic, rubber and wood. The team discussed the concept of using the remote to make it look more environmentally friendly. The group discussed the use of a remote that could be used in the future. They discussed the cost of the battery, and discussed the feasibility of using solar cells, and how they would be used to power the remote, and what materials they would like to use. They also discussed how they might use the remote could be', "The Project Manager and the Project Manager of the project. The Project Manager will introduce the project manager to the group. The project manager will discuss the project's goals and objectives. The group will also discuss how to make a remote control that can be used to control the remote. The team will then discuss how they will use the remote control. They will then use the project to create a user friendly and user friendly interface. The meeting manager will then give a presentation on the project and discuss the group's goals. The first meeting will take place in the meeting room. The company will discuss their goals and goals for the project, and the group will discuss what they will do with the project"]
# 7.581799030303955
# ["The project manager presented the project manager's presentation. The marketing expert gave a presentation on the remote control design. The project manager also presented the presentation of the remote remote. The group then discussed the remote's design features. The team decided to make a decision about the remote. They decided to put two additional requirements on the project. They also discussed the possibility of making a remote that could be used in the future. They discussed the idea of using a remote to make it easier to use for television. The company decided to use the remote to communicate with the user. They then decided to decide whether to use a remote control to communicate via text message. The meeting manager then presented the product to the", "The new remote control is designed to be user-friendly and user- friendly. The originality of the remote will be the user-friendliness of the device. The group will discuss the design of the new remote. The marketing team will discuss marketing and marketing ideas. The team will also discuss the product market. They will discuss how to sell the remote. They'll also discuss how they would like to use the remote to make it easier for users to use their own devices. The project manager and the marketing team would discuss the project manager would discuss their ideas. They also discuss their favourite characteristics of the product. They would discuss how the remote could be used to control a remote."]
# 6.207676887512207
# ["The Industrial Designer is the Industrial Designer for the project. The Industrial Designer will be responsible for the design of the remote control. The Marketing Expert is the Marketing Expert. He will discuss the project's marketing strategy and the product design. He'll also discuss the design and marketing requirements for the remote remote. The Project Manager will also discuss how the remote will be used to control the remote, and how to use the remote. He has the idea of using a remote to find out if the remote can be used for a remote, but the remote is always missing. The User Interface Designer will discuss how to make a remote that can be controlled by a remote control device. The project manager will", "The remote is based on anti-theft technology. It's based on the anti- theft technology for suitcases. The remote is designed to be easy to use and easy to put on the back of the remote. The colour of the device is not a special colour, but it's not special. The company has decided to make a special design for the remote, but the colour is not special because of the colour. They have decided to use it in the design. They also decided to put it on the front of the screen. They decided to include a rubber rubber casing and a rubber casing. They would like to use the remote to make it easier to use. The"]
# 7.281054496765137
# ['The project manager and the project manager are meeting to discuss the product design. The project manager is meeting with the marketing team to discuss their marketing strategy. The marketing team is also meeting for the first time to discuss how to make the product look. The team will discuss the design of the device, the colour, and the user interface. The group will also discuss how they would like to use the scroll wheel to be able to use it in the future. The meeting will also cover the cost of the project. The first meeting will take place in the early hours of the day. The final meeting will be held on the same day as the meeting, and then the team will decide whether to', "The User Interface Designer and the Marketing Expert are meeting to discuss the project. The Marketing Expert and the User Interface Expert will discuss the design of the remote control. They will also discuss the price of the project and how to make the remote remote. The User Interface designer and the marketing expert will discuss what the project will cost and how they would like to use the remote to control the remote. They'll also discuss how they should be able to make a remote control that can be used to make it look like a human. The marketing expert would discuss the remote and the user interface interface. The project manager will also talk about the project manager's role in the marketing strategy. The group will"]
# 7.017595291137695
# ['The concept of the user interface of the device is discussed. The user interface is designed to be simple and easy to use. The main features are the buttons, the buttons and the buttons. The buttons are different shapes and they are used to control the volume and volume. They are also used to adjust the brightness and the volume of the channel. The remote control is a simple set of buttons that can be easily accessed by using a remote. The menu is designed for the remote, and the remote can be used to make it easier to use for remote control. The design of the remote will be discussed with the user. The project manager will also discuss the design of a remote control device. The', 'The User Interface Designer and the Marketing Manager are meeting to discuss the project. The User Interface designer and the marketing manager are also meeting. The Marketing Manager and the User Interface Interface Designer are meeting for the first time. They will discuss the design of the remote, and the user interface designer. The marketing manager and the interface designer will discuss their ideas. The project manager will present their ideas to the user. The group will also discuss the technical functions of the device. The user interface developer will discuss how to use the remote control. The team will discuss what features they think the remote will have, and how to make it look and how they would like to use it. The remote designer will']
# 7.642824172973633
# ["The Project Manager and the Project Manager are meeting to discuss their ideas for the project. The project manager and the project manager are meeting for the first time to discuss the product's design. The group will discuss the design of the product, the price of the device, and how it will be used. They will also discuss the idea of using a remote control. The team will discuss how to use the remote control, and then discuss the user interface. They also discuss how they would like to use it to be used in the remote. They'll also discuss what features they think the product will have to be included in the product. The meeting will also include a menu, the menu,", "The project manager and secretary of the project manager are meeting to discuss the project. The project manager is also meeting with the project management. The meeting manager is meeting with a group of project managers. The group is also discussing the project budget and the project project manager's role in the meeting. The marketing manager will also discuss the company's marketing strategy and marketing strategy. The team will discuss the product design and the marketing strategy for the remote control. The company will discuss their product design. They will discuss how they would like to use the remote and marketing their products in the future. They also discuss their marketing strategy, and how they will use the project marketing strategy to promote their products. They discussed"]
# 8.335269927978516
# ["The industrial designer. The industrial designer's role in the project is to be the industrial designer, and the project manager. The project manager's role is to work out the project's goals and objectives. The marketing expert's role will be in the marketing team's role. The group will have to discuss the project goals of the project. They will also have to decide whether they want to use the remote to make it easier to use. The team will also discuss the cost of the product. The meeting will also be held on the subject of marketing. They'll also discuss how to make the product look like it would be easy to use in the remote. The company will then decide whether to", "The project manager. The project manager presented the project manager's presentation presentation. The team discussed the meeting's decision to make the project look at the cost of the project. The meeting also discussed the possibility of using rubber, rubber, wood, titanium, and rubber and wood. The group also discussed how to make a case for the project, which they would like to use. They decided to use a rubber case and rubber case. They discussed the idea of using a battery and rubber to make it look like it would be a special case. The first meeting meeting was held in order to decide whether to use rubber and rubber. The next meeting will be held in a meeting to discuss the"]
# 7.236328125
# ["The group will discuss the costs of the remote, the materials and the materials for the remote. The group will also discuss the features of the buttons, the buttons and the buttons. They will discuss how to make the remote easier to use and how to use the buttons to make it look like a remote. They'll also discuss what they think they will use in the remote control. They also discuss how they would like to use a remote to control the remote and how they want to make a remote that can be used to control a remote with a remote, which they think will be easy to use. And then they'll discuss the cost of the device, which will be more expensive, and how", "The new remote control is designed to be a simple, simple and simple remote control. The remote is designed for the remote, and the remote is based on the design of the remote. The new remote has a remote control that sends a signal from the remote to the remote that sends out an infrared light to the television, and then sends it to a remote. This remote is a remote that can be used to communicate with a remote, but the remote can be controlled by a remote remote. It can also be used on a remote with an integrated remote, or a remote to control the remote's remote. So the remote will be used for the first time to control a remote for the"]
# 6.891397953033447
# ['The Project Manager and the Project Manager. The Project Manager discussed the idea of combining plastic and rubber with rubber and rubber. The project manager and the project manager discussed the design of the project. The team discussed the possibility of combining the materials and materials to create the product. The product designer discussed the need to have the on-off button on the front of the case. The group discussed how they would like to use the case to make the case look like a banana. The marketing expert discussed how to make a case and how to use a rubber case. They discussed the cost of the components and how they should be used in the design. They also discussed the feasibility of using special materials', 'The Marketing Manager and the Marketing Manager are meeting to discuss the needs and desires of the group. The Marketing Manager is meeting with the group to discuss what they want to do with the project. The group also discussed the need for a full screen. The marketing manager and the marketing manager discussed the needs of the project and the budget. They also discussed how to make the project look like it should be designed to be a product. They discussed the budget for the project, and how they would like to have a full-screen screen. They decided that the project should be a project that could be designed for children. The project manager and marketing manager would discuss the product design and marketing materials. The']
# 7.113204479217529
# ["The project manager and the project manager are meeting to discuss the project's financial objective. The project manager is also meeting with the marketing team. The team will discuss the design of the remote and the marketing side of the project. The group will also discuss the idea of using a remote to make a remote that can be used in a remote. They will discuss how to make it look like a remote and how to use a remote with a remote control. The first meeting will be held on the basis of the user's opinion. The second meeting will also be held in the same format as the first meeting. The final meeting will take place on the second day of the meeting, and the group will", 'The team decided to use a special colour to make the buttons special. The team decided that the buttons should be made special. They decided that they should be special because of their colour. The group decided to make a special design. The design team decided they should use the special colour. They also discussed the possibility of using a special power button. They discussed the cost of the buttons, and how they would be used in the design. They then decided that it would be easier to use the power button and not be too expensive to use. The project manager decided that a special button should be used for the speech recognition. The marketing team then decided to decide whether to use it in a special way']
# 1
# 5.150670051574707
# 5.3340888023376465
# 5.517684459686279
# 5.827995300292969
# 5.075045585632324
# 4.803268909454346
# 5.182016372680664
# 5.22374153137207
# 5.566041469573975
# 5.423236846923828
# 5.56278133392334
# 4.047533988952637
# 5.5142822265625
# 5.160610198974609
# 4.952260494232178
# 4.8498640060424805
# 5.341179370880127
# 5.3047990798950195
# 5.54871940612793
# 4.720067977905273
# 5.203482627868652
# 5.43507194519043
# 5.009651184082031
# 4.297907829284668
# 5.7435078620910645
# 5.1805949211120605
# 4.804972171783447
# 5.124483108520508
# 5.210969924926758
# 5.592065334320068
# 5.5600905418396
# 4.72705078125
# 4.682966232299805
# 4.968139171600342
# 4.726284503936768
# 5.006204605102539
# 5.191987991333008
# 5.337716102600098
# 5.28110408782959
# 4.38709020614624
# 4.541215896606445
# 3.90081787109375
# 4.508962631225586
# 4.168097972869873
# 5.346545219421387
# 4.356494903564453
# 4.489977836608887
# 5.246241569519043
# 5.032196521759033
# 5.0367560386657715
# 4.698798179626465
# 5.932492256164551
# 5.011307716369629
# 5.076714992523193
# 4.991926670074463
# Validation
# 6.337041854858398
# ['The marketing expert gave a presentation on the project. The marketing expert presented the project to the team members. The group discussed the need for a remote to be able to control the remote. The team discussed the possibility of using the remote to make the remote easier to use. They also discussed the cost of the remote and how to use it to control a remote. They discussed the use of a remote control. The project manager suggested that a remote should be used in the future. The industrial designer suggested that the remote could be used to control remote control and that the marketing expert should use the remote control to make it easier to communicate with the user. The meeting was also discussed that the project manager should', 'The project manager opened the meeting to discuss the project and the budget. The marketing expert presented the project to the group. The group then discussed the project budget, and discussed the design of the remote. The team then discussed how they would like to use the remote to make it easier to use. The project manager presented the product to the team, and the group discussed the cost of the project, and how they wanted to use it to make the remote more affordable. They discussed the possibility of using the remote control to reduce the costs of the device. They also discussed the feasibility of using a remote control. They decided to use a remote to control the remote, and that it would be easier to']
# 6.862791061401367
# ['The group discussed the possibility of using a remote to control the remote. They discussed the cost of the remote, and discussed the need for a remote that could be used to control a remote. The group also discussed the use of a remote control device. They also discussed how they would use the remote to make the remote easier to control. The team decided to use a remote for the first time that it would be easier to use for the second time. The marketing team decided that the remote should be used for the last time to market the remote as a remote and that it should not be used in the marketing tool. They decided that a remote should not have a remote with a remote function. The', "The project manager and the marketing manager opened the meeting and discussed the project. The marketing expert presented the project to the group. The group then discussed the product design and the user interface. The project manager presented the group the project manager described as the group's first meeting. The team then discussed what the group would like to do with the remote control. The designer discussed the marketing strategy for the project, which included the use of a remote control, and how they would like it to be used by the user to control the remote. They discussed how to use the remote and how to make the project easier to use. They decided to use a remote, and the group discussed the cost of the project"]
# 6.286314010620117
# ["The project manager opened the meeting to discuss the project. The marketing expert presented the project manager's findings and presented the results of the project to the group. The group then discussed the requirements for the remote control. The team then decided to decide whether to use the remote to control the remote. The project manager presented the group's findings to the team and the group decided to make a decision on whether to buy a remote for the next project. They then discussed their findings and discussed the needs of a remote control, which included the need for a remote to have a remote that could be used to control a remote. They discussed the need to be able to use a remote with a remote or a remote", 'The meeting will be held at the same time as the meeting. The group will discuss the future of the remote, and then discuss the cost of the project. The meeting will also discuss the possibility of using the remote to control the remote. The team will then decide whether to use the remote as a remote. They will then discuss how to make the remote look like a remote, which they would like to use in the future. The marketing expert will also present the product to the group. The project manager will present the project to the team, and the team will discuss their findings on the design of the device. The industrial designer will present a prototype of a remote that could be used in']
# 6.847146034240723
# ["The marketing expert gave a presentation of the meeting's agenda. The marketing expert presented the group's agenda for the meeting. The group then discussed the future of the remote control. They discussed the possibility of using the remote to communicate with each other. They also discussed how to use the remote and how to make the remote easier to use. The team then discussed how they would like to incorporate the remote into their marketing strategy. They decided that the remote should be used in the marketing tool. They then decided that they should not use the remotes to communicate and that it would not be too expensive to do so. They were also considering using a remote control for the remote.    and that", 'The project manager and the project manager presented the project to the group. The marketing expert presented the product to the team and the marketing expert. The industrial designer presented the prototype of the device. The group then discussed the marketing strategy for the project. The team then decided to use the marketing tool to market the product. The project manager gave the group a brief overview of the project before the group discussed the product design. They discussed the project and discussed the requirements of the marketing team. They also discussed the cost of the product, and discussed how they would like to use it to be used in the market. They then decided that the project should be designed to be easy to use, and that the']
# 7.023106575012207
# ["The Project Manager and the Project Manager presented the project to the group of participants. The Project Manager gave the group a presentation of the components of the project. The group discussed the project manager's decision to make the project look at the remote. The team discussed the possibility of using rubber, rubber, plastic, rubber and wood to make it look like it would be easy to use. The project manager also discussed the idea of using a rubber screen to make a remote that could be used in the future. The marketing expert suggested that the remote should be shaped like a rubber case and a rubber casing. He also suggested that it should have a rubber-based design. The industrial designer presented the", "The Project Manager and the Project Manager presented the project to the members of the team. The Project Manager introduced the project manager to the group. The project manager introduced the group to the meeting and the group discussed the project's goals and objectives. The group then discussed the goals of the project and discussed their goals and goals for the project. The team then discussed their objectives for the next meeting. They discussed their priorities for the product. They then discussed how they would like to use the remote control to make it more user friendly. They also discussed the possibility of using the remote to control the remote. They decided that the project should be designed to be original, trendy and user-friendly. The"]
# 7.218435287475586
# ['The marketing expert opened the meeting and presented the project requirements. The marketing expert presented the requirements of the remote control. The project manager presented the product requirements to the marketing expert. The group then discussed the requirements for the remote, and discussed the features of the product. The Marketing expert then presented the results of the meeting to the group. The team then discussed their findings and discussed what features they would like to include in the remote. They discussed the product design. They decided that the remote should be used for television, and that it should not be a remote that could be used in the future. They also discussed the possibility of using the remote to make it easier to use the remote remote. The', 'The marketing expert presented the project to the group. The industrial designer presented the industrial design of the remote control. The marketing expert gave the group a brief overview of the project. The group then discussed the marketing and marketing requirements for the remote. The project manager presented the product to the team, the marketing expert, and the industrial designer. The team discussed the project manager, the industrial expert and the project expert. They discussed the product design, the user interface, and how they would like to use the remote to be used in the future. The final meeting was held on the same day and the group discussed the meeting agenda. The meeting was then adjourned until the group decided to decide whether to']
# 5.7816667556762695
# ["The Industrial Designer presented the project to the Industrial Designer. The Industrial Designer opened the meeting and discussed the project's requirements for the remote control. The Marketing Expert presented the product requirements for a remote control that could be used to control the remote. The industrial designer presented the final prototype of the remote, which was designed by a team of engineers. The team then discussed the requirements of the product designer and the marketing expert. The marketing expert discussed the remote and marketing expert about the product design. The group then decided to discuss the product specifications for the final product. The project manager then gave the group a prototype of a remote that would be used in a remote, and the group decided to use the remote", 'The remote is based on anti-theft technology. The remote is designed to be easy to control, but the remote is not easy to use. The company has decided that the remote should have a special colour. They also decided that it should be a rubber-based design. The team decided to make the remote look more like a remote. The group decided that they would like to use the remote to control the remote. They decided to use a rubber casing to make it easier to operate. The marketing team decided that a rubber case would be the ideal for the remote, and that it would not be difficult to use to control it. The project manager and the marketing expert discussed the possibility of']
# 6.831141948699951
# ['The marketing expert opened the meeting and opened the agenda for the meeting. The marketing expert gave a presentation of the product. The industrial designer presented the product to the audience. The group then discussed the marketing strategy for the project. The team discussed the possibility of using a remote control to control the display. The project manager presented the project to the group and the marketing expert. They discussed the project manager and the team members discussed the cost of the project and the industrial design options. They also discussed the feasibility of using the remote control, and discussed the use of a remote to control a remote. The meeting was also discussed by the industrial designer, and the group discussed the need for a remote-controlled', 'The User Interface Designer and the Marketing Expert discussed the project. The Marketing Expert and the User Interface Expert discussed what they would like to do with the remote control. They discussed how to make a remote that can be used on a remote. They also discussed the possibility of using a remote control that could be used to control the remote. The marketing expert discussed the need for a remote to be able to use the remote to make the remote look like a human. The group discussed the cost of the remote and how to use it to make it easier to use. The project manager suggested that a remote should be used for the remote, but the marketing expert suggested that it should be a remote with a remote']
# 6.5377702713012695
# ['The team will discuss the user interface features of the device. The team will then decide whether to include a menu for the remote. The group will also discuss how to make the device look like a remote control. They will then discuss the features that they would like to include in the menu. They also discussed how to use the remote to control the remote, and how to adjust the volume of the television. They decided to include some of the functions that would be useful to the user. They discussed the idea of using the remote control to control a remote. They then discussed the design of the remote and how they would be able to use it in the future. They were also considering the possibility of', 'The User Interface Designer and the Marketing Manager are meeting to discuss the project. The Marketing Manager and the User Interface Interface Designer are meeting for the first time to discuss their ideas. The User Interface designer is meeting with the marketing manager and the marketing expert. The marketing expert is also meeting the project manager to discuss his ideas for the remote control. The industrial designer will discuss the design of the remote, and the user interface designer will also discuss the features of the device. The project manager is meeting the marketing team to discuss what features the remote will have, and what features they would like to have. The group will discuss how to make the remote look and how to use the remote. They will discuss']
# 7.245162010192871
# ['The Project Manager and the Project Manager opened the meeting to discuss the project. The Project Manager introduced the project manager to the group and the group discussed their ideas for a remote control. The group then discussed the features of the remote, the menu, and the user interface, and how to use the remote. The project manager then opened the project to discuss their ideas. The team then discussed their plans for the project and discussed the product design. The marketing expert suggested that the remote should be more user-friendly, and that the group should be able to use it as a remote. They also discussed the possibility of using the remote control to make it easier to navigate and to make the device easier', 'The project manager opened the meeting and opened the agenda. The project manager introduced the project manager to the project management. The marketing expert opened the presentation and discussed the project budget. The group then discussed the marketing strategy for the remote control. The team then discussed how they would like to use the remote to be able to control the remote. They discussed the cost of the project, and discussed how to make the remote, and how to use it in the future.    the group discussed the possibility of using the remotes to make it more affordable.  The team discussed the feasibility of using a remote control for the next two years. The meeting was then adjourned and the group decided to']
# 7.932903289794922
# ['The industrial designer presented the project to the industrial designer. The industrial designer explained that the project goal was to have a remote control that would be easy to use. The marketing expert discussed the project goals of the project and discussed the needs of the marketing expert. The group then discussed the need for a remote to be more user friendly. The team then discussed how they would like to use the remote to make it easier to use, and how to use it more easily. The project manager also discussed the cost of the remote, and the project manager discussed the possibility of using the remote control to make the device more affordable.    The group also discussed how to make a remote that could be easily', "The project manager presented the project to the team and the team. The team then discussed the cost of the project. The group then decided to decide whether to make the project more affordable. The marketing expert presented the team with a presentation of the meeting's objectives. The project manager discussed the project budget for the project, and the project manager suggested that the project should be re-imagined. The industrial designer discussed the marketing strategy for the product, which included the use of a rubber case, and how to make a case for the energy source. The meeting also discussed the possibility of using a battery, and whether to use an LCD screen, and what to do with a remote control, and which"]
# 6.790641784667969
# ["The group will discuss the costs of the remote, and then discuss the options for the remote. The group will also discuss the features of the remotes, which will be used in the future. The team will then discuss how to make the remote look like a remote. They will then decide whether to use the remote to make it easier to use for the first time. They'll also discuss whether to include a remote with a remote control, and whether to make a remote that can be used for the second time, and how to use a remote for the third time. And then, they'll discuss the cost of the device, and if they want to sell it to the group, they will", "The project manager presented the project to the team. The marketing expert presented a presentation of the project. The industrial designer presented the industrial design of the remote control. The team discussed the project manager's role in the marketing strategy. The group then discussed the design of a remote control that could be used in the future. The project manager also discussed the possibility of using the remote to control the remote. The final product was the remote, and the marketing expert gave a presentation on the project, and discussed the cost of the device, and how to make a remote that would be used to control a remote.  The team decided to use the remote for the first time since the project was launched, and"]
# 6.472633361816406
# ["The prototype was designed to be simple, simple, and easy to use. The prototype was shown to the team and the team members. The team members discussed the design of the prototype. The marketing team discussed the idea of using a rubber case to make the device more affordable. The group discussed the possibility of using special materials for the device. They also discussed the need for a rubber-based design. They discussed the cost of the device, which they would like to use to make it more affordable, and how to use the remote control. The project manager discussed the marketing team's decision to use a remote control to control the remote. The industrial designer discussed the use of the remote, and the", "The Marketing Manager and the Marketing Manager presented the group's agenda for the meeting. The group discussed the needs and desires of the group. The marketing manager presented the meeting's agenda and the group discussed their priorities. The Marketing Manager then presented the agenda and opened the meeting for the group to discuss their objectives. The next meeting will be held on the agenda of the next meeting, and then the group will discuss the budget for the marketing team. The final meeting will also discuss the marketing strategy and marketing strategy for the company.    The group will then decide whether to use the marketing tool for the project.  The marketing team will then discuss their priorities for the future marketing strategy.  They"]
# 6.649107456207275
# ["The project manager opened the meeting to discuss the project's financial objective. The project manager presented the project manager's financial objectives. The marketing expert presented the marketing side of the project. The industrial designer presented the industrial design of the remote control. The group discussed the need for a remote that could be used in the future. The team then discussed the feasibility of using a remote to be able to control multiple devices. They discussed the cost of a remote and discussed the possibility of using the remote to make a profit from the sale of the device.    The group then discussed how they would like to sell the remote on the basis of the price of the product.  The team also discussed the", 'The project manager presented the project to the group. The marketing expert presented the presentation of the project. The group discussed the marketing strategy, and discussed the need for a special colour. The team then discussed the cost of the marketing materials, and how to make the project more affordable. They discussed the possibility of using a remote control to control the remote. The project manager suggested that a remote could be used to control a remote, and that the remote should be used for a remote. They also discussed the use of a remote to control an LCD screen. They decided to use a remote for the remote, but the remote was not available. They then decided to make a remote with a remote and remote']
# 2
# 4.108294486999512
# 4.77341890335083
# 4.7889580726623535
# 5.032675743103027
# 4.777660846710205
# 5.187921047210693
# 5.27753210067749
# 5.3087992668151855
# 5.2502827644348145
# 4.846861839294434
# 5.507737159729004
# 4.73634147644043
# 3.9689974784851074
# 4.676994323730469
# 5.211983680725098
# 5.148771286010742
# 4.419923782348633
# 4.62037467956543
# 5.194406509399414
# 5.138860702514648
# 5.294849395751953
# 5.043179988861084
# 4.848902225494385
# 4.933800220489502
# 4.1693854331970215
# 3.5530765056610107
# 5.054074764251709
# 5.048029899597168
# 4.39884090423584
# 5.142012596130371
# 5.009335517883301
# 4.884937286376953
# 4.959897994995117
# 5.3300700187683105
# 4.430910110473633
# 4.785983562469482
# 4.612752914428711
# 4.631824970245361
# 4.801549911499023
# 4.523707389831543
# 4.644649982452393
# 5.165968894958496
# 4.722347736358643
# 4.879246711730957
# 4.021919250488281
# 5.158073425292969
# 4.855515003204346
# 4.307267189025879
# 5.205278396606445
# 4.004432201385498
# 5.1547393798828125
# 5.316719055175781
# 4.730057716369629
# 5.148975372314453
# 4.990431785583496
# Validation
# 6.210080146789551
# ['The Project Manager and the Project Manager opened the meeting. The Project Manager introduced the project manager and the group discussed the project budget for the project. The group discussed how to make the project look like a remote. The marketing expert presented the project to the group and the team members. The project manager presented the prototype of the project and discussed the need for a remote control. The team members discussed the possibility of using a remote to control the remote. They discussed the idea of using an LCD screen to make it look like it would be easy to control a remote, but the group decided not to use the LCD screen because of the cost of the device. They decided to use a LCD screen', 'The project manager opened the meeting and opened a meeting with the group members. The group discussed the project budget, and discussed the features of the remote. The project manager gave the group an overview of the project. The marketing expert gave a presentation of the prototype design. The team members discussed the design of the device, and the project manager discussed the cost of remotes. They discussed the possibility of using a remote control to make the remote easier to control. They also discussed the need for a remote that could be used in the future. They decided to use the remote to control the remote, and that it should not be too expensive. The user interface designer suggested that the remote should be']
# 6.700483322143555
# ["The Project Manager presented the project to the group. The Project Manager gave a brief presentation of the project. The group discussed the possibility of using a remote control device to control the remote. The project manager gave a presentation of what the project manager would like to do with the remote control. The marketing expert presented the product to the team. The team members discussed the project and discussed the cost of the remotes. They discussed the need for a remote that could be used to control a remote. They decided that the remote should be used in the remote and that it should not be used as a remote for children. They also discussed the idea of using the remote to control children's remote.", 'The Project Manager and the Project Manager opened the meeting. The Project Manager presented the project to the group members. The group discussed the project budget for the project. The marketing expert presented a prototype of a remote that could be used to control the remote. The project manager presented the prototype of the remote control. The team members discussed their favorite animal characteristics, which included a dog, a cat, a rat, a dog and a bird, and the project manager suggested that the remote should be used for the remote, but the group decided not to use it. They decided to use the remote to control their remote. ']
# 6.206254959106445
# ...
# 6.535462379455566
# ['The Project Manager and the Marketing Expert opened the meeting. The Marketing Expert introduced the project to the group. The Project Manager introduced the group to the project manager and the group members. The group then discussed the project budget for the project. The User Interface Designer presented the project and the Project Manager gave the group a brief introduction to the product design. The marketing expert presented the product to the marketing expert. The team then discussed how to incorporate the project into the design of the product. The project manager then gave the team a brief presentation on the product and the team members discussed how they would like to use the product in the future. ', 'The project manager opened the meeting. The marketing expert presented the project to the group. The industrial designer presented the prototype and discussed the project process. The group then discussed the cost of the project. The team then discussed how they would like to use the device to make it easier to use. The project manager presented the product to the team and the team members. They discussed the product process and the marketing strategy for the product. They also discussed the role of the user in the marketing. ']
# 6.75213623046875
# ['The project manager opened the meeting to discuss the project. The project manager introduced the project to the group. The group then discussed the project budget for the project and the overall cost of the product. The marketing expert gave a presentation on the project, the project manager and the group members, the marketing expert, and the team members. The team members discussed the role of the project leader, the group member, the team member, and their personal preferences, the user interface, the product designer, the manufacturer, the cost of their product, the materials and the marketing specialist, the industrial designer, and they discussed the product design. They discussed the possibility of using a rubber case to make the device more', 'The project manager opened the meeting by saying that the project manager will introduce the project to the group. The project manager introduced the project management team to the team members. The group then discussed the project budget and the project process. The team then decided to create a prototype of the remote control. The marketing expert gave a presentation on the project and the group discussed the product design.    the team decided to make the project look more user-friendly.  the group decided to use the product as well as the user interface. ']
# 6.955087661743164
# ['The project manager opened the meeting by stating that the project manager had received the project report from the previous meeting. The marketing expert presented the project requirements to the group. The project manager presented the results of the project to the team. The group then discussed the requirements of the product design. The team then decided to make a decision on the project design. They decided to decide on whether to include an LCD screen, a touch screen, and whether to use the LCD screen. They also decided to include a LCD screen on the display. They discussed the possibility of using a touch-screen to make the remote look like it would have been used in the future. ', 'The Project Manager and the Project Manager opened the meeting. The Project Manager introduced the project to the group and the group members. The Marketing Expert presented the project and discussed the project budget for the project. The Industrial Designer presented the prototype of the prototype. The group discussed the prototype design and the project manager presented the product to the team. The marketing expert discussed the product design. The project manager suggested that the project should be designed to be more user-friendly. The team members discussed their personal experiences with the product. They discussed their favorite characteristics of the product, which included the use of a remote control, and their personal preferences for the design. They also discussed the cost of the device']
# 5.455517768859863
# ["The project manager opened the meeting and opened the discussion about the project. The marketing expert discussed the project budget for the product. The industrial designer discussed the product market for the first time. The project manager discussed the role of the marketing expert in the product design. The group then discussed the cost of the project, and how to make the product look. The team then decided to make a profit from the project by selling the product on the basis of the success of the group's success. ", 'The project manager opened the meeting. The project manager presented the project to the team members. The marketing expert presented the product to the group. The group discussed the product design and the overall cost of the project. The team discussed the project budget and the materials involved in the design. They discussed the possibility of using an LCD screen to make the remote easier to use. The product designer discussed the need for a LCD screen, the cost of batteries, and how to incorporate the LCD screen into the design of the device. They also discussed the use of a rubber casing to make it easier for the remote to be used in the remote. They decided that they would like to use a rubber case. The']
# 6.571051597595215
# ['The project manager opened the meeting by saying that the project was a success. The project manager then introduced the project manager and the marketing expert to the team. The group then discussed the project budget and the overall cost of the project. The marketing expert presented the project to the group. The team then discussed their budget for the project, and discussed the possibility of using an LCD screen. They discussed the feasibility of using the LCD screen to make the device easier to use. They also discussed the cost of using a scroll wheel to make it easier for the user to control the display. The industrial designer discussed the use of the LCD LCD screen, and how to incorporate the LCD into the design of the device', "The Project Manager and the Project Manager opened the meeting and discussed the project. The Project Manager introduced the project to the group members. The Marketing Expert discussed the group's decision to make the project more user-friendly. The User Interface Designer presented the project manager and the Marketing Expert. The group then discussed their decision to use the project budget for the product. They discussed the cost of the project and how they would like it to be made. The project manager suggested that the group should be able to sell the project by the end of the year. "]
# 6.215940475463867
# ["The Project Manager and the Project Manager presented the project to the group. The Project Manager opened the meeting and the group discussed the project. The group then discussed the requirements of the project and the project manager. The team then decided that they would like to include a menu in the design. The project manager suggested that the group should include a custom-designed menu. The marketing expert suggested that a menu should be included in the product. The next meeting will discuss the group's initial requirements for the project, which includes the ability to use the menu, and the overall cost of the device, and how to make the device look. The final meeting will also discuss the project budget, which will include", 'The Project Manager and the User Interface Designer opened the meeting. They discussed the project and discussed the requirements of the user interface. The Project Manager opened the discussion about the project. The Marketing Manager introduced the project to the group and the group discussed the product market. The group then discussed the components of the remote control. The project manager introduced the product to the team and the marketing team. The marketing team discussed how they would like to use the product. The team then discussed how to make the product available for the group. They decided to use it as a remote for the next project. They also discussed the cost of the product and how to incorporate the design into the product design. The']
# 6.872150897979736
# ['The Project Manager opened the meeting and discussed the project. The Project Manager introduced the project to the group. The group then discussed the product design. The project manager introduced the product to the team and the team members. The marketing expert presented the project manager and the marketing expert and the group discussed the prototype. The team discussed the design of the product and the project budget for the product. They also discussed the cost of the project, and how they would like it to be marketed to the general public. They discussed the possibility of using an LCD screen to make the device more user-friendly. ', 'The project manager opened the meeting. The project manager introduced the project manager to the team. The group then discussed the project budget and the project management. The marketing expert presented the project plan and the budget. The team discussed the cost of the project, and how they would like to sell the product to the market. ']
# 7.604170799255371
# ["The project manager opened the meeting by saying that the project goal was to have a new device that would be easy to use. The project manager then opened the discussion about the project's objectives. The marketing expert opened the discussions about the product design. The group then discussed the project budget, and the project manager's role in the project. The team then discussed their goals for the product.    the group then decided that the product should have a different design. ", "The project manager opened the meeting. The project manager presented the project to the team members. The team then discussed the project budget and the cost of the project. The marketing expert presented the group's findings and presented the findings of their findings. The group then discussed their findings on the project costs, and discussed the possibility of using a rubber case to make the project easier to use. The next meeting will be the next meeting to decide whether the project will be held in the future. The meeting will also discuss the feasibility of using rubber, rubber, wood, and titanium in the design. "]
# 6.504709243774414
# ["The project manager opened the meeting. The project manager presented the project to the group members. The group then discussed the project budget and the project costs. The marketing expert presented the results of the project and presented the findings of the group's findings. The team then discussed their findings on the project. They then discussed how to make the project look like they would like to make it easier to use. They also discussed the possibility of using an LCD screen, and how to use a rubber casing. They discussed the cost of the device, which they decided would be too expensive. They concluded that the project should be completed by the end of the meeting, and that the team should decide whether to use the", 'The project manager opened the meeting and discussed the project budget for the project. The project manager presented the project to the team and the team members. The marketing expert discussed the role of the project manager in the marketing strategy. The team discussed the possibility of using an LCD screen to make the remote. The group then discussed the cost of the device, and how to incorporate the LCD screen into the design. They decided to use a LCD screen and LCD screen. They also discussed how to use the LCD to display the color of the screen, and whether to use it on the LCD. They discussed the feasibility of using LCD screens and whether they would be able to use LCD screens. They then decided to']
# 6.138032913208008
# ['The project manager opened the meeting. The marketing expert gave a presentation on the project. The industrial designer presented the project to the team and the team members. The project manager discussed the project budget and the product budget. The team then decided that the project should be more affordable. The group then decided to decide whether to make a case for the device. The prototype was designed to be simple, but the team decided to use it as a case. The product designer discussed the possibility of using an LCD screen to make the device easier to use. The user interface designer discussed how to use the LCD screen, and how to incorporate the LCD into the design of the device, and the marketing expert discussed the', 'The Project Manager introduced the project to the group. The Project Manager opened the meeting by saying that the group had a discussion about the project. The Marketing Manager then introduced the group to the project manager and the group members. The group then discussed the project budget and the project process. The marketing expert presented the project plan for the product. The project manager presented the product to the marketing team and the marketing expert. The team discussed the product design and the budget for the project, which they decided to use as a marketing tool. They discussed the cost of the project and how they would like to make the project more affordable. They decided that the project should not be too expensive and that the']
# 6.329442024230957
# ['The project manager opened the meeting by saying that the project will be a success. The project manager introduced the project manager to the team members. The group then discussed the project budget, the project cost and the product size. The marketing expert presented the project plan for the project. The industrial designer presented the product to the group. The team then discussed how to make the product look and how to incorporate the design into the design. They discussed the cost of the project and how they would like to sell the product. They also discussed the possibility of using a battery-powered device. ', 'The project manager opened the meeting. The marketing expert presented the project to the group. The group discussed the cost of the project. The project manager discussed the possibility of using an LCD screen to make the device more affordable. The team then decided to use the LCD screen instead of the LCD. They decided to include a LCD screen, a LCD, and the LCD to display. They also decided to incorporate a LCD to make it easier to use. They then decided that the LCD would be too expensive to use, and that it would not be easy to use with a LCD. The prototype was designed by the group and the group decided that they should use a LCD instead of a LCD display. The']

# %%
plt.plot(training_results[0]['training_loss'], label="train")
plt.plot(training_results[0]['validation_loss'], label="val")
plt.ylabel('loss')
plt.xlabel('iterations')
plt.legend()
#plt.title('training loss iterations')

# %%
training_results[1]
# Out:
# {'rouge1': 41.775, 'rouge2': 14.303, 'rougeL': 25.0082, 'rougeLsum': 39.5555}

# %%
# !nvidia-smi
